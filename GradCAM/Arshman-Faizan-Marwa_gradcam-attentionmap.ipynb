# %% [markdown]
# ##  Loading the libraries and dataframes

# %%
#!pip install timm

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import torch
import torch.nn as nn
import torch.optim as optim
import time
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.models import efficientnet_b0, resnet18 
import timm
from PIL import Image
from sklearn.metrics import precision_recall_fscore_support
import torch.nn.functional as F
from torchvision.utils import save_image
from torch.amp import autocast, GradScaler

# --- GLOBAL CONFIGURATION ---
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BASE_DIR = '/kaggle/input/final-project-deep-learning-fall-2025/final_project_resources'
IMAGE_DIR = os.path.join(BASE_DIR, 'images')
IMG_SIZE = 256
DISEASE_COLUMNS = ['D', 'G', 'A']
TEAM_ID = "Arshman-Faizan-Marwa" # Updated Kaggle Team Name 

# --- LOAD DATAFRAMES ---
train_df = pd.read_csv(os.path.join(BASE_DIR, 'train.csv'))
val_df = pd.read_csv(os.path.join(BASE_DIR, 'val.csv'))
offsite_test_df = pd.read_csv(os.path.join(BASE_DIR, 'offsite_test.csv'))

print(f"Setup complete. Training on: {DEVICE}")
print(f"Train samples: {len(train_df)}")
print(f"Validation samples: {len(val_df)}")
print(f"Offsite Test samples: {len(offsite_test_df)}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# Setup complete. Training on: cuda
# Train samples: 800
# Validation samples: 200
# Offsite Test samples: 200

# %% [markdown]
# ##  Implement Image Dataset and DataLoaders

# %%
class ODIRDataset(Dataset):
    def __init__(self, df, image_dir, mode='train'):
        self.df = df
        self.image_dir = image_dir
        self.mode = mode
        
        if mode == 'train':
            self.image_folder = os.path.join(image_dir, 'train')
        elif mode == 'val':
            self.image_folder = os.path.join(image_dir, 'val')
        elif mode in ['test', 'offsite_test']:
            self.image_folder = os.path.join(image_dir, 'offsite_test') 
        elif mode == 'test_onsite':
            self.image_folder = os.path.join(image_dir, 'onsite_test')
        
        self.transform = self._get_transforms(mode)

    def _get_transforms(self, mode):
        normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        if mode == 'train':
            return transforms.Compose([
                transforms.Resize((IMG_SIZE, IMG_SIZE)),
                transforms.RandomHorizontalFlip(p=0.5),
                transforms.RandomVerticalFlip(p=0.5),
                transforms.RandomRotation(15),
                transforms.ToTensor(),
                normalize
            ])
        return transforms.Compose([
            transforms.Resize((IMG_SIZE, IMG_SIZE)),
            transforms.ToTensor(),
            normalize
        ])

    def __len__(self): return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        image_path = os.path.join(self.image_folder, row['id'])
        image = Image.open(image_path).convert("RGB")
        image = self.transform(image)
        if self.mode != 'test_onsite': 
            labels = torch.tensor(row[DISEASE_COLUMNS].values.astype(float), dtype=torch.float32)
            return image, labels
        return image, row['id']

# Initialize Loaders
train_loader = DataLoader(ODIRDataset(train_df, IMAGE_DIR, 'train'), batch_size=32, shuffle=True)
val_loader = DataLoader(ODIRDataset(val_df, IMAGE_DIR, 'val'), batch_size=32, shuffle=False)
offsite_loader = DataLoader(ODIRDataset(offsite_test_df, IMAGE_DIR, 'test'), batch_size=32, shuffle=False)

# %% [markdown]
# ## Data Exploration and Disease Distribution Visualization

# %%
# Columns representing the three major diseases
DISEASE_COLUMNS = ['D', 'G', 'A']

# Calculate the count of each disease in the training set
disease_counts = train_df[DISEASE_COLUMNS].sum()

# --- Plotting the Distribution  ---
plt.figure(figsize=(8, 6))
bars = plt.bar(disease_counts.index, disease_counts.values, color=['green', 'blue', 'red'])

# Add the counts on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 10, int(yval), ha='center', va='bottom', fontsize=12)

plt.title('Distribution of Diseases in Training Dataset')
plt.xlabel('Disease Type')
plt.ylabel('Number of Images')
plt.ylim(0, 550) # Set limit based on the document's visualization
plt.grid(axis='y', linestyle='--')

# Save the plot for the report 
CHART_PATH = 'disease_distribution_train.png'
plt.savefig(CHART_PATH)
plt.show()

print(f"Disease distribution chart saved to: {CHART_PATH}")
# Output will confirm the imbalance: D: 517, G: 163, A: 142 [cite: 50, 56, 57]
# Out:
# Disease distribution chart saved to: disease_distribution_train.png

# %% [markdown]
# ## VAE Image Generation

# %%
# =========================
# Create writable VAE training image directory
# =========================

VAE_TRAIN_DIR = "/kaggle/working/images/train"
os.makedirs(VAE_TRAIN_DIR, exist_ok=True)

print("Writable VAE train directory:", VAE_TRAIN_DIR)
# Out:
# Writable VAE train directory: /kaggle/working/images/train

# %%
# =========================
# Copy original training images to working directory
# =========================

import shutil

ORIG_TRAIN_DIR = os.path.join(IMAGE_DIR, "train")

for fname in os.listdir(ORIG_TRAIN_DIR):
    src = os.path.join(ORIG_TRAIN_DIR, fname)
    dst = os.path.join(VAE_TRAIN_DIR, fname)
    if not os.path.exists(dst):
        shutil.copy(src, dst)

print("Original training images copied to working directory.")
# Out:
# Original training images copied to working directory.

# %%
class ConvVAE(nn.Module):
    def __init__(self, latent_dim=128):
        super().__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, 4, 2, 1),   # 128x128
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, 2, 1),  # 64x64
            nn.ReLU(),
            nn.Conv2d(64, 128, 4, 2, 1), # 32x32
            nn.ReLU(),
            nn.Conv2d(128, 256, 4, 2, 1),# 16x16
            nn.ReLU(),
        )

        self.fc_mu = nn.Linear(256 * 16 * 16, latent_dim)
        self.fc_logvar = nn.Linear(256 * 16 * 16, latent_dim)

        # Decoder
        self.fc_dec = nn.Linear(latent_dim, 256 * 16 * 16)
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, 4, 2, 1),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, 4, 2, 1),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, 4, 2, 1),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, 4, 2, 1),
            nn.Sigmoid()
        )

    def encode(self, x):
        h = self.encoder(x).view(x.size(0), -1)
        return self.fc_mu(h), self.fc_logvar(h)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        h = self.fc_dec(z).view(-1, 256, 16, 16)
        return self.decoder(h)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        recon = self.decode(z)
        return recon, mu, logvar

# %%
# VAE loss
def vae_loss(recon, x, mu, logvar):
    recon_loss = F.mse_loss(recon, x, reduction='sum')
    kl = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return recon_loss + kl


# Dataset for single class
class SingleClassDataset(Dataset):
    def __init__(self, csv_file, image_dir, class_idx):
        self.df = pd.read_csv(csv_file)
        self.df = self.df[self.df.iloc[:, class_idx + 1] == 1]
        self.image_dir = image_dir
        self.transform = transforms.Compose([
            transforms.Resize((256, 256)),
            transforms.ToTensor()
        ])

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.df.iloc[idx, 0])
        img = Image.open(img_path).convert("RGB")
        return self.transform(img)


def train_vae(class_idx, epochs=30):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    dataset = SingleClassDataset(
        csv_file="/kaggle/input/final-project-deep-learning-fall-2025/final_project_resources/train.csv",
        image_dir="/kaggle/input/final-project-deep-learning-fall-2025/final_project_resources/images/train",
        class_idx=class_idx
    )
    loader = DataLoader(dataset, batch_size=16, shuffle=True)

    model = ConvVAE().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for imgs in loader:
            imgs = imgs.to(device)
            recon, mu, logvar = model(imgs)
            loss = vae_loss(recon, imgs, mu, logvar)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        print(f"Class {class_idx} | Epoch {epoch+1} | Loss {total_loss/len(dataset):.2f}")

    return model

# %%
def generate_images(model, num_images, save_dir, prefix):
    device = next(model.parameters()).device
    model.eval()
    with torch.no_grad():
        for i in range(num_images):
            z = torch.randn(1, 128).to(device)
            img = model.decode(z)
            save_image(img, os.path.join(save_dir, f"{prefix}_vae_{i}.png"))


# Train VAEs
vae_G = train_vae(class_idx=1)  # Glaucoma
vae_A = train_vae(class_idx=2)  # AMD

# Generate images to balance classes
generate_images(vae_G, 354, VAE_TRAIN_DIR, "G")
generate_images(vae_A, 375, VAE_TRAIN_DIR, "A")
# Out:
# Class 1 | Epoch 1 | Loss 24077.17
# Class 1 | Epoch 2 | Loss 23664.18
# Class 1 | Epoch 3 | Loss 21602.15
# Class 1 | Epoch 4 | Loss 15905.18
# Class 1 | Epoch 5 | Loss 10609.05
# Class 1 | Epoch 6 | Loss 7539.59
# Class 1 | Epoch 7 | Loss 6187.29
# Class 1 | Epoch 8 | Loss 5332.56
# Class 1 | Epoch 9 | Loss 4715.03
# Class 1 | Epoch 10 | Loss 4279.98
# Class 1 | Epoch 11 | Loss 3930.88
# Class 1 | Epoch 12 | Loss 3578.11
# Class 1 | Epoch 13 | Loss 3299.17
# Class 1 | Epoch 14 | Loss 3103.38
# Class 1 | Epoch 15 | Loss 2852.74
# Class 1 | Epoch 16 | Loss 2672.90
# Class 1 | Epoch 17 | Loss 2503.79
# Class 1 | Epoch 18 | Loss 2336.65
# Class 1 | Epoch 19 | Loss 2203.69
# Class 1 | Epoch 20 | Loss 2062.29
# Class 1 | Epoch 21 | Loss 1991.34
# Class 1 | Epoch 22 | Loss 1849.38
# Class 1 | Epoch 23 | Loss 1722.57
# Class 1 | Epoch 24 | Loss 1644.07
# Class 1 | Epoch 25 | Loss 1563.95
# Class 1 | Epoch 26 | Loss 1578.47
# Class 1 | Epoch 27 | Loss 1500.90
# Class 1 | Epoch 28 | Loss 1444.70
# Class 1 | Epoch 29 | Loss 1374.90
# Class 1 | Epoch 30 | Loss 1301.15
# Class 2 | Epoch 1 | Loss 18220.07
# Class 2 | Epoch 2 | Loss 17617.34
# Class 2 | Epoch 3 | Loss 15416.52
# Class 2 | Epoch 4 | Loss 10779.72
# Class 2 | Epoch 5 | Loss 7792.23
# Class 2 | Epoch 6 | Loss 6544.57
# Class 2 | Epoch 7 | Loss 5842.98
# Class 2 | Epoch 8 | Loss 5299.60
# Class 2 | Epoch 9 | Loss 4858.33
# Class 2 | Epoch 10 | Loss 4471.34
# Class 2 | Epoch 11 | Loss 4104.46
# Class 2 | Epoch 12 | Loss 3752.52
# Class 2 | Epoch 13 | Loss 3426.49
# Class 2 | Epoch 14 | Loss 3099.34
# Class 2 | Epoch 15 | Loss 2831.57
# Class 2 | Epoch 16 | Loss 2584.32
# Class 2 | Epoch 17 | Loss 2356.83
# Class 2 | Epoch 18 | Loss 2169.61
# Class 2 | Epoch 19 | Loss 2023.96
# Class 2 | Epoch 20 | Loss 1897.13
# Class 2 | Epoch 21 | Loss 1803.89
# Class 2 | Epoch 22 | Loss 1731.57
# Class 2 | Epoch 23 | Loss 1676.22
# Class 2 | Epoch 24 | Loss 1588.24
# Class 2 | Epoch 25 | Loss 1558.95
# Class 2 | Epoch 26 | Loss 1492.39
# Class 2 | Epoch 27 | Loss 1451.42
# Class 2 | Epoch 28 | Loss 1398.26
# Class 2 | Epoch 29 | Loss 1333.90
# Class 2 | Epoch 30 | Loss 1310.41

# %%
df = train_df

new_rows = []

for i in range(354):
    new_rows.append([f"G_vae_{i}.png", 0, 1, 0])

for i in range(375):
    new_rows.append([f"A_vae_{i}.png", 0, 0, 1])

df_vae = pd.concat(
    [df, pd.DataFrame(new_rows, columns=df.columns)],
    ignore_index=True
)

df_vae.to_csv("train_vae.csv", index=False)

print("New training set size:", len(df_vae))
# Out:
# New training set size: 1529

# %% [markdown]
# ### Initializing the Train Data Loader (again)

# %%
# Initialize Loaders
train_df = pd.read_csv("train_vae.csv")
train_loader = DataLoader(ODIRDataset(train_df, "/kaggle/working/images", 'train'), batch_size=32, shuffle=True)

# %% [markdown]
# ## Updated Disease Distribution Visualization

# %%
# =========================
# Dataset Distribution AFTER VAE Augmentation
# =========================

# Columns representing the three major diseases
DISEASE_COLUMNS = ['D', 'G', 'A']

# Calculate the count of each disease in the training set
disease_counts = train_df[DISEASE_COLUMNS].sum()

plt.figure(figsize=(8, 6))
bars = plt.bar(disease_counts.index, disease_counts.values,
               color=['green', 'blue', 'red'])

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2,
             yval + 10,
             int(yval),
             ha='center',
             va='bottom',
             fontsize=12)

plt.title('Distribution of Diseases in Training Dataset (After VAE Augmentation)')
plt.xlabel('Disease Type')
plt.ylabel('Number of Images')
plt.ylim(0, 550)
plt.grid(axis='y', linestyle='--')

CHART_PATH_VAE = 'disease_distribution_train_vae.png'
plt.savefig(CHART_PATH_VAE)
plt.show()

print(f"VAE-augmented disease distribution chart saved to: {CHART_PATH_VAE}")
# Out:
# VAE-augmented disease distribution chart saved to: disease_distribution_train_vae.png

# %%
print("Train CSV rows:", len(train_df))
print("Train image files:", len(os.listdir("/kaggle/working/images/train")))

print("Sample image paths:")
for i in range(5):
    print(os.path.join("/kaggle/working/images/train", train_df.iloc[i]['id']))
# Out:
# Train CSV rows: 1529
# Train image files: 1529
# Sample image paths:
# /kaggle/working/images/train/913_right.jpg
# /kaggle/working/images/train/281_left.jpg
# /kaggle/working/images/train/3981_left.jpg
# /kaggle/working/images/train/4449_right.jpg
# /kaggle/working/images/train/4497_right.jpg

# %%
def show_split_samples(df, image_root, split_name, mode, n=5):
    """
    df         : dataframe for the split
    image_root: base image directory
    split_name: title for display
    mode       : 'train', 'val', 'offsite_test', 'test_onsite'
    """

    print(f"\n===== {split_name} CSV HEAD =====")
    display(df.head())

    # Resolve image folder exactly as Dataset does
    if mode == 'train':
        img_dir = os.path.join(image_root, 'train')
    elif mode == 'val':
        img_dir = os.path.join(image_root, 'val')
    elif mode in ['test', 'offsite_test']:
        img_dir = os.path.join(image_root, 'offsite_test')
    elif mode == 'test_onsite':
        img_dir = os.path.join(image_root, 'onsite_test')

    print(f"\n===== {split_name} SAMPLE IMAGES =====")

    fig, axes = plt.subplots(1, n, figsize=(15, 4))
    for i in range(n):
        img_path = os.path.join(img_dir, df.iloc[i]['id'])
        img = Image.open(img_path).convert("RGB")
        axes[i].imshow(img)
        axes[i].axis("off")
        axes[i].set_title(df.iloc[i]['id'], fontsize=8)

    plt.tight_layout()
    plt.show()

# %%
# TRAIN (VAE-augmented)
show_split_samples(
    train_df,
    "/kaggle/working/images",
    "TRAIN (VAE-Augmented)",
    mode="train"
)

# VALIDATION
show_split_samples(
    val_df,
    IMAGE_DIR,
    "VALIDATION",
    mode="val"
)

# OFFSITE TEST
show_split_samples(
    offsite_test_df,
    IMAGE_DIR,
    "OFFSITE TEST",
    mode="offsite_test"
)

# ONSITE TEST
onsite_test_df = pd.read_csv(os.path.join(BASE_DIR, 'onsite_test_submission.csv'))

show_split_samples(
    onsite_test_df,
    IMAGE_DIR,
    "ONSITE TEST",
    mode="test_onsite"
)
# Out:
# ===== TRAIN (VAE-Augmented) CSV HEAD =====
#                id  D  G  A
# 0   913_right.jpg  1  0  0
# 1    281_left.jpg  1  0  0
# 2   3981_left.jpg  1  0  0
# 3  4449_right.jpg  1  0  0
# 4  4497_right.jpg  1  0  0
# ===== TRAIN (VAE-Augmented) SAMPLE IMAGES =====
# ===== VALIDATION CSV HEAD =====
#                id  D  G  A
# 0   184_right.jpg  1  0  0
# 1   4488_left.jpg  1  0  0
# 2  4050_right.jpg  1  0  0
# 3  4485_right.jpg  1  0  0
# 4   4338_left.jpg  1  0  0
# ===== VALIDATION SAMPLE IMAGES =====
# ===== OFFSITE TEST CSV HEAD =====
#                id  D  G  A
# 0   568_right.jpg  1  0  0
# 1    748_left.jpg  1  0  0
# 2   649_right.jpg  1  0  0
# 3    991_left.jpg  1  0  0
# 4  4252_right.jpg  1  0  0
# ===== OFFSITE TEST SAMPLE IMAGES =====
# ===== ONSITE TEST CSV HEAD =====
#                id  D  G  A
# 0  4595_right.jpg  0  0  0
# 1   4155_left.jpg  0  0  0
# 2    597_left.jpg  0  0  0
# 3  4268_right.jpg  0  0  0
# 4   579_right.jpg  0  0  0
# ===== ONSITE TEST SAMPLE IMAGES =====

# %% [markdown]
# # Task 1: Transfer Learning Implementation

# %%
class TransferModel(nn.Module):
    def __init__(self, backbone, num_classes=3):
        super().__init__()
        self.backbone = backbone
        if hasattr(self.backbone, 'fc'):
            in_features = self.backbone.fc.in_features
            self.backbone.fc = nn.Identity()
        elif hasattr(self.backbone, 'classifier'):
            in_features = self.backbone.classifier[1].in_features
            self.backbone.classifier = nn.Identity()
        elif hasattr(self.backbone, 'num_features'):  # ViT / Swin
            in_features = self.backbone.num_features
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        features = self.backbone(x)
        if features.dim() > 2:
            features = features.view(features.size(0), -1)
        return self.classifier(features)

def evaluate_and_print_metrics(model, data_loader, task_name, model_label):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for inputs, labels in data_loader:
            outputs = model(inputs.to(DEVICE))
            preds = (torch.sigmoid(outputs) > 0.5).int().cpu().numpy()
            all_preds.append(preds)
            all_labels.append(labels.cpu().numpy())
    
    all_preds, all_labels = np.concatenate(all_preds), np.concatenate(all_labels)
    precision, recall, fscore, _ = precision_recall_fscore_support(all_labels, all_preds, average=None, zero_division=0)
    avg_fscore = fscore.mean()
    
    print(f"\n--- {task_name} Metrics ({model_label}) ---")
    print(f"Average F-score: {avg_fscore:.4f}")
    diseases = ["DR", "Glaucoma", "AMD"]
    for i in range(3):
        print(f"{diseases[i]}: F-score={fscore[i]:.4f}, Precision={precision[i]:.4f}, Recall={recall[i]:.4f}")
    return avg_fscore

def generate_onsite_submission(model, save_path):
    model.eval()
    template = pd.read_csv(os.path.join(BASE_DIR, 'onsite_test_submission.csv'))
    onsite_loader = DataLoader(ODIRDataset(template, IMAGE_DIR, 'test_onsite'), batch_size=32)
    results = []
    with torch.no_grad():
        for inputs, ids in onsite_loader:
            outputs = model(inputs.to(DEVICE))
            preds = (torch.sigmoid(outputs) > 0.5).int().cpu().numpy()
            for i in range(len(ids)):
                results.append({'id': ids[i], 'D': preds[i,0], 'G': preds[i,1], 'A': preds[i,2]})
    pd.DataFrame(results).to_csv(save_path, index=False)
    print(f"Onsite Submission saved to: {save_path}")

# def load_backbone_only(model, checkpoint_filename):
#     path = os.path.join(BASE_DIR, f'pretrained_backbone/{checkpoint_filename}')
#     ckpt = torch.load(path, map_location=DEVICE)
#     for key in ['classifier.1.weight', 'classifier.1.bias', 'fc.weight', 'fc.bias']:
#         if key in ckpt: del ckpt[key]
#     model.load_state_dict(ckpt, strict=False)
#     return model.to(DEVICE)



def load_backbone_only(model, full_checkpoint_path):
    """
    Loads weights from a FULL path and removes classifier keys.
    """
    # Load the checkpoint directly from the path provided
    checkpoint = torch.load(full_checkpoint_path, map_location=DEVICE)
    
    
    mismatched_keys = ['classifier.1.weight', 'classifier.1.bias', 'fc.weight', 'fc.bias']
    for key in mismatched_keys:
        if key in checkpoint:
            del checkpoint[key]

    model.load_state_dict(checkpoint, strict=False)
    return model.to(DEVICE)

# %%
def get_loaded_backbone(model_func, checkpoint_filename):
    """
    Constructs the path once and calls the loader.
    """
    # 1. Instantiate base model
    backbone = model_func(weights=None) 
    
    # 2. Build the FULL path 
    full_path = os.path.join(BASE_DIR, f'pretrained_backbone/{checkpoint_filename}')
    
    # 3. Pass the clean path to the loader
    return load_backbone_only(backbone, full_path)

# %% [markdown]
# ## Task 1.1 - Baseline Evaluation (Offsite Metrics + Onsite File)

# %%
print("Running Task 1.1 Baselines...")

def run_1_1(model_func, ckpt, label):
    model = model_func(num_classes=3).to(DEVICE)
    model.load_state_dict(torch.load(os.path.join(BASE_DIR, f'pretrained_backbone/{ckpt}'), map_location=DEVICE))
    evaluate_and_print_metrics(model, offsite_loader, "Task 1.1", label)
    generate_onsite_submission(model, f"{TEAM_ID}_task1-1_{label}.csv")

run_1_1(efficientnet_b0, 'ckpt_efficientnet_ep50.pt', 'eff')
run_1_1(resnet18, 'ckpt_resnet18_ep50.pt', 'res')
# Out:
# Running Task 1.1 Baselines...
#
# --- Task 1.1 Metrics (eff) ---
# Average F-score: 0.5541
# DR: F-score=0.6947, Precision=0.7459, Recall=0.6500
# Glaucoma: F-score=0.5941, Precision=0.5769, Recall=0.6122
# AMD: F-score=0.3736, Precision=0.2464, Recall=0.7727
# Onsite Submission saved to: Arshman-Faizan-Marwa_task1-1_eff.csv
#
# --- Task 1.1 Metrics (res) ---
# Average F-score: 0.5126
# DR: F-score=0.5941, Precision=0.7172, Recall=0.5071
# Glaucoma: F-score=0.5169, Precision=0.5750, Recall=0.4694
# AMD: F-score=0.4267, Precision=0.3019, Recall=0.7273
# Onsite Submission saved to: Arshman-Faizan-Marwa_task1-1_res.csv

# %% [markdown]
# ## Task 1.2: Frozen Backbone, Fine-Tune Classifier Only

# %%
def train_model(model, optimizer, criterion, epochs, model_label, task_label):
    best_f1 = 0
    save_path = f"Arshman-Faizan-Marwa_{task_label}_{model_label}.pt"
    for epoch in range(1, epochs+1):
        model.train()
        for img, lbl in train_loader:
            optimizer.zero_grad()
            loss = criterion(model(img.to(DEVICE)), lbl.to(DEVICE))
            loss.backward(); optimizer.step()
        
        f1 = evaluate_and_print_metrics(model, val_loader, f"Epoch {epoch}", model_label)
        if f1 > best_f1:
            best_f1 = f1
            torch.save(model.state_dict(), save_path)
    return save_path

# %% [markdown]
# ## Task 1.2(a): Training and Evaluation (EfficientNet)

# %%
eff_ckpt_path = os.path.join(BASE_DIR, 'pretrained_backbone/ckpt_efficientnet_ep50.pt')

# --- EfficientNet Task 1.2 ---
model_eff = TransferModel(load_backbone_only(efficientnet_b0(weights=None), eff_ckpt_path)).to(DEVICE)
for param in model_eff.backbone.parameters(): param.requires_grad = False
opt = optim.Adam(model_eff.classifier.parameters(), lr=1e-3)

best_path = train_model(model_eff, opt, nn.BCEWithLogitsLoss(), 25, "EffNet", "task1-2")
model_eff.load_state_dict(torch.load(best_path))
evaluate_and_print_metrics(model_eff, offsite_loader, "Task 1.2 Final", "EffNet")
generate_onsite_submission(model_eff, f"{TEAM_ID}_task1-2_eff.csv")
# Out:
# --- Epoch 1 Metrics (EffNet) ---
# Average F-score: 0.4885
# DR: F-score=0.7809, Precision=0.6901, Recall=0.8991
# Glaucoma: F-score=0.6847, Precision=0.7170, Recall=0.6552
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Epoch 2 Metrics (EffNet) ---
# Average F-score: 0.6336
# DR: F-score=0.7967, Precision=0.7273, Recall=0.8807
# Glaucoma: F-score=0.6800, Precision=0.8095, Recall=0.5862
# AMD: F-score=0.4242, Precision=0.6364, Recall=0.3182
#
# --- Epoch 3 Metrics (EffNet) ---
# Average F-score: 0.6348
# DR: F-score=0.8189, Precision=0.7172, Recall=0.9541
# Glaucoma: F-score=0.6522, Precision=0.8824, Recall=0.5172
# AMD: F-score=0.4333, Precision=0.8125, Recall=0.2955
#
# --- Epoch 4 Metrics (EffNet) ---
# Average F-score: 0.6430
# DR: F-score=0.7917, Precision=0.7252, Recall=0.8716
# Glaucoma: F-score=0.6735, Precision=0.8250, Recall=0.5690
# AMD: F-score=0.4638, Precision=0.6400, Recall=0.3636
#
# --- Epoch 5 Metrics (EffNet) ---
# Average F-score: 0.6090
# DR: F-score=0.7950, Precision=0.7308, Recall=0.8716
# Glaucoma: F-score=0.6931, Precision=0.8140, Recall=0.6034
# AMD: F-score=0.3390, Precision=0.6667, Recall=0.2273
#
# --- Epoch 6 Metrics (EffNet) ---
# Average F-score: 0.6307
# DR: F-score=0.7937, Precision=0.6993, Recall=0.9174
# Glaucoma: F-score=0.6804, Precision=0.8462, Recall=0.5690
# AMD: F-score=0.4179, Precision=0.6087, Recall=0.3182
#
# --- Epoch 7 Metrics (EffNet) ---
# Average F-score: 0.6125
# DR: F-score=0.7865, Precision=0.6646, Recall=0.9633
# Glaucoma: F-score=0.5747, Precision=0.8621, Recall=0.4310
# AMD: F-score=0.4762, Precision=0.7895, Recall=0.3409
#
# --- Epoch 8 Metrics (EffNet) ---
# Average F-score: 0.5339
# DR: F-score=0.7826, Precision=0.6467, Recall=0.9908
# Glaucoma: F-score=0.4054, Precision=0.9375, Recall=0.2586
# AMD: F-score=0.4138, Precision=0.8571, Recall=0.2727
#
# --- Epoch 9 Metrics (EffNet) ---
# Average F-score: 0.6255
# DR: F-score=0.7769, Precision=0.7068, Recall=0.8624
# Glaucoma: F-score=0.6452, Precision=0.8571, Recall=0.5172
# AMD: F-score=0.4545, Precision=0.6818, Recall=0.3409
#
# --- Epoch 10 Metrics (EffNet) ---
# Average F-score: 0.6354
# DR: F-score=0.7833, Precision=0.7176, Recall=0.8624
# Glaucoma: F-score=0.5647, Precision=0.8889, Recall=0.4138
# AMD: F-score=0.5581, Precision=0.5714, Recall=0.5455
#
# --- Epoch 11 Metrics (EffNet) ---
# Average F-score: 0.6582
# DR: F-score=0.7863, Precision=0.7360, Recall=0.8440
# Glaucoma: F-score=0.6667, Precision=0.8421, Recall=0.5517
# AMD: F-score=0.5217, Precision=0.7200, Recall=0.4091
#
# --- Epoch 12 Metrics (EffNet) ---
# Average F-score: 0.6261
# DR: F-score=0.7854, Precision=0.7029, Recall=0.8899
# Glaucoma: F-score=0.6735, Precision=0.8250, Recall=0.5690
# AMD: F-score=0.4194, Precision=0.7222, Recall=0.2955
#
# --- Epoch 13 Metrics (EffNet) ---
# Average F-score: 0.6474
# DR: F-score=0.7984, Precision=0.7122, Recall=0.9083
# Glaucoma: F-score=0.6087, Precision=0.8235, Recall=0.4828
# AMD: F-score=0.5352, Precision=0.7037, Recall=0.4318
#
# --- Epoch 14 Metrics (EffNet) ---
# Average F-score: 0.6068
# DR: F-score=0.8031, Precision=0.7034, Recall=0.9358
# Glaucoma: F-score=0.5412, Precision=0.8519, Recall=0.3966
# AMD: F-score=0.4762, Precision=0.7895, Recall=0.3409
#
# --- Epoch 15 Metrics (EffNet) ---
# Average F-score: 0.6569
# DR: F-score=0.8097, Precision=0.7246, Recall=0.9174
# Glaucoma: F-score=0.6531, Precision=0.8000, Recall=0.5517
# AMD: F-score=0.5079, Precision=0.8421, Recall=0.3636
#
# --- Epoch 16 Metrics (EffNet) ---
# Average F-score: 0.6499
# DR: F-score=0.7897, Precision=0.7419, Recall=0.8440
# Glaucoma: F-score=0.6383, Precision=0.8333, Recall=0.5172
# AMD: F-score=0.5217, Precision=0.7200, Recall=0.4091
#
# --- Epoch 17 Metrics (EffNet) ---
# Average F-score: 0.6349
# DR: F-score=0.7788, Precision=0.7521, Recall=0.8073
# Glaucoma: F-score=0.6458, Precision=0.8158, Recall=0.5345
# AMD: F-score=0.4800, Precision=0.5806, Recall=0.4091
#
# --- Epoch 18 Metrics (EffNet) ---
# Average F-score: 0.6550
# DR: F-score=0.7967, Precision=0.7273, Recall=0.8807
# Glaucoma: F-score=0.6452, Precision=0.8571, Recall=0.5172
# AMD: F-score=0.5231, Precision=0.8095, Recall=0.3864
#
# --- Epoch 19 Metrics (EffNet) ---
# Average F-score: 0.6356
# DR: F-score=0.7489, Precision=0.7455, Recall=0.7523
# Glaucoma: F-score=0.6923, Precision=0.7826, Recall=0.6207
# AMD: F-score=0.4658, Precision=0.5862, Recall=0.3864
#
# --- Epoch 20 Metrics (EffNet) ---
# Average F-score: 0.6240
# DR: F-score=0.7647, Precision=0.7054, Recall=0.8349
# Glaucoma: F-score=0.6408, Precision=0.7333, Recall=0.5690
# AMD: F-score=0.4667, Precision=0.8750, Recall=0.3182
#
# --- Epoch 21 Metrics (EffNet) ---
# Average F-score: 0.6460
# DR: F-score=0.7899, Precision=0.7287, Recall=0.8624
# Glaucoma: F-score=0.6400, Precision=0.7619, Recall=0.5517
# AMD: F-score=0.5079, Precision=0.8421, Recall=0.3636
#
# --- Epoch 22 Metrics (EffNet) ---
# Average F-score: 0.6622
# DR: F-score=0.8000, Precision=0.7092, Recall=0.9174
# Glaucoma: F-score=0.6327, Precision=0.7750, Recall=0.5345
# AMD: F-score=0.5538, Precision=0.8571, Recall=0.4091
#
# --- Epoch 23 Metrics (EffNet) ---
# Average F-score: 0.6286
# DR: F-score=0.7421, Precision=0.7321, Recall=0.7523
# Glaucoma: F-score=0.6105, Precision=0.7838, Recall=0.5000
# AMD: F-score=0.5333, Precision=0.5217, Recall=0.5455
#
# --- Epoch 24 Metrics (EffNet) ---
# Average F-score: 0.6555
# DR: F-score=0.8112, Precision=0.7214, Recall=0.9266
# Glaucoma: F-score=0.6392, Precision=0.7949, Recall=0.5345
# AMD: F-score=0.5161, Precision=0.8889, Recall=0.3636
#
# --- Epoch 25 Metrics (EffNet) ---
# Average F-score: 0.6359
# DR: F-score=0.7787, Precision=0.7037, Recall=0.8716
# Glaucoma: F-score=0.6061, Precision=0.7317, Recall=0.5172
# AMD: F-score=0.5231, Precision=0.8095, Recall=0.3864
#
# --- Task 1.2 Final Metrics (EffNet) ---
# Average F-score: 0.7167
# DR: F-score=0.8737, Precision=0.8366, Recall=0.9143
# Glaucoma: F-score=0.6098, Precision=0.7576, Recall=0.5102
# AMD: F-score=0.6667, Precision=0.8571, Recall=0.5455
# Onsite Submission saved to: Arshman-Faizan-Marwa_task1-2_eff.csv

# %% [markdown]
# ## Task 1.2(b): Training and Evaluation (ResNet18)

# %%
# --- ResNet18 Task 1.2 (Following your EfficientNet Logic) ---
print("Task 1.2 for ResNet18...")
res_ckpt_path = os.path.join(BASE_DIR, 'pretrained_backbone/ckpt_resnet18_ep50.pt')
# 1. Setup Model: Load ResNet18 backbone, strip head, and move to DEVICE
# This uses the specific ResNet checkpoint: ckpt_resnet18_ep50.pt
model_res = TransferModel(
    load_backbone_only(resnet18(weights=None), res_ckpt_path)
).to(DEVICE)

# 2. FREEZE the ResNet backbone (Crucial for Task 1.2)
for param in model_res.backbone.parameters(): 
    param.requires_grad = False

# 3. Setup Optimizer for the classifier head only
opt_res = optim.Adam(model_res.classifier.parameters(), lr=1e-3)

# 4. Train using existing train_model function
# Running for 25 epochs 
best_path_res = train_model(
    model_res, 
    opt_res, 
    nn.BCEWithLogitsLoss(), 
    25, 
    "ResNet", 
    "task1-2"
)

# 5. Load the best saved weights
model_res.load_state_dict(torch.load(best_path_res))

# 6. Final Evaluation on Offsite Test Set
evaluate_and_print_metrics(model_res, offsite_loader, "Task 1.2 Final", "ResNet")

# 7. Generate Onsite Submission for Kaggle (Target: 61.4)
generate_onsite_submission(model_res, f"{TEAM_ID}_task1-2_res.csv")
# Out:
# Task 1.2 for ResNet18...
#
# --- Epoch 1 Metrics (ResNet) ---
# Average F-score: 0.3875
# DR: F-score=0.7143, Precision=0.5848, Recall=0.9174
# Glaucoma: F-score=0.3611, Precision=0.9286, Recall=0.2241
# AMD: F-score=0.0870, Precision=1.0000, Recall=0.0455
#
# --- Epoch 2 Metrics (ResNet) ---
# Average F-score: 0.3556
# DR: F-score=0.7287, Precision=0.6309, Recall=0.8624
# Glaucoma: F-score=0.3380, Precision=0.9231, Recall=0.2069
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Epoch 3 Metrics (ResNet) ---
# Average F-score: 0.3506
# DR: F-score=0.7138, Precision=0.5638, Recall=0.9725
# Glaucoma: F-score=0.3380, Precision=0.9231, Recall=0.2069
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Epoch 4 Metrics (ResNet) ---
# Average F-score: 0.5402
# DR: F-score=0.7536, Precision=0.7959, Recall=0.7156
# Glaucoma: F-score=0.5567, Precision=0.6923, Recall=0.4655
# AMD: F-score=0.3103, Precision=0.6429, Recall=0.2045
#
# --- Epoch 5 Metrics (ResNet) ---
# Average F-score: 0.4631
# DR: F-score=0.7576, Precision=0.6452, Recall=0.9174
# Glaucoma: F-score=0.4054, Precision=0.9375, Recall=0.2586
# AMD: F-score=0.2264, Precision=0.6667, Recall=0.1364
#
# --- Epoch 6 Metrics (ResNet) ---
# Average F-score: 0.4020
# DR: F-score=0.7426, Precision=0.6196, Recall=0.9266
# Glaucoma: F-score=0.4634, Precision=0.7917, Recall=0.3276
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Epoch 7 Metrics (ResNet) ---
# Average F-score: 0.3676
# DR: F-score=0.7418, Precision=0.6145, Recall=0.9358
# Glaucoma: F-score=0.3611, Precision=0.9286, Recall=0.2241
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Epoch 8 Metrics (ResNet) ---
# Average F-score: 0.4513
# DR: F-score=0.7826, Precision=0.6875, Recall=0.9083
# Glaucoma: F-score=0.5714, Precision=0.9231, Recall=0.4138
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Epoch 9 Metrics (ResNet) ---
# Average F-score: 0.4941
# DR: F-score=0.7692, Precision=0.6623, Recall=0.9174
# Glaucoma: F-score=0.4675, Precision=0.9474, Recall=0.3103
# AMD: F-score=0.2456, Precision=0.5385, Recall=0.1591
#
# --- Epoch 10 Metrics (ResNet) ---
# Average F-score: 0.4259
# DR: F-score=0.7591, Precision=0.6303, Recall=0.9541
# Glaucoma: F-score=0.5185, Precision=0.9130, Recall=0.3621
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Epoch 11 Metrics (ResNet) ---
# Average F-score: 0.4435
# DR: F-score=0.7528, Precision=0.6296, Recall=0.9358
# Glaucoma: F-score=0.5778, Precision=0.8125, Recall=0.4483
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Epoch 12 Metrics (ResNet) ---
# Average F-score: 0.4564
# DR: F-score=0.7520, Precision=0.6667, Recall=0.8624
# Glaucoma: F-score=0.5301, Precision=0.8800, Recall=0.3793
# AMD: F-score=0.0870, Precision=1.0000, Recall=0.0455
#
# --- Epoch 13 Metrics (ResNet) ---
# Average F-score: 0.4659
# DR: F-score=0.7578, Precision=0.6599, Recall=0.8899
# Glaucoma: F-score=0.6400, Precision=0.7619, Recall=0.5517
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Epoch 14 Metrics (ResNet) ---
# Average F-score: 0.4682
# DR: F-score=0.7630, Precision=0.6398, Recall=0.9450
# Glaucoma: F-score=0.4416, Precision=0.8947, Recall=0.2931
# AMD: F-score=0.2000, Precision=0.8333, Recall=0.1136
#
# --- Epoch 15 Metrics (ResNet) ---
# Average F-score: 0.4373
# DR: F-score=0.7518, Precision=0.6242, Recall=0.9450
# Glaucoma: F-score=0.4324, Precision=1.0000, Recall=0.2759
# AMD: F-score=0.1277, Precision=1.0000, Recall=0.0682
#
# --- Epoch 16 Metrics (ResNet) ---
# Average F-score: 0.4701
# DR: F-score=0.7765, Precision=0.6781, Recall=0.9083
# Glaucoma: F-score=0.4416, Precision=0.8947, Recall=0.2931
# AMD: F-score=0.1923, Precision=0.6250, Recall=0.1136
#
# --- Epoch 17 Metrics (ResNet) ---
# Average F-score: 0.5325
# DR: F-score=0.7576, Precision=0.6452, Recall=0.9174
# Glaucoma: F-score=0.5349, Precision=0.8214, Recall=0.3966
# AMD: F-score=0.3051, Precision=0.6000, Recall=0.2045
#
# --- Epoch 18 Metrics (ResNet) ---
# Average F-score: 0.5031
# DR: F-score=0.7435, Precision=0.6250, Recall=0.9174
# Glaucoma: F-score=0.4324, Precision=1.0000, Recall=0.2759
# AMD: F-score=0.3333, Precision=0.6250, Recall=0.2273
#
# --- Epoch 19 Metrics (ResNet) ---
# Average F-score: 0.4649
# DR: F-score=0.7407, Precision=0.6211, Recall=0.9174
# Glaucoma: F-score=0.4615, Precision=0.9000, Recall=0.3103
# AMD: F-score=0.1923, Precision=0.6250, Recall=0.1136
#
# --- Epoch 20 Metrics (ResNet) ---
# Average F-score: 0.4726
# DR: F-score=0.7639, Precision=0.7177, Recall=0.8165
# Glaucoma: F-score=0.6538, Precision=0.7391, Recall=0.5862
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Epoch 21 Metrics (ResNet) ---
# Average F-score: 0.4487
# DR: F-score=0.7529, Precision=0.6429, Recall=0.9083
# Glaucoma: F-score=0.4267, Precision=0.9412, Recall=0.2759
# AMD: F-score=0.1667, Precision=1.0000, Recall=0.0909
#
# --- Epoch 22 Metrics (ResNet) ---
# Average F-score: 0.5456
# DR: F-score=0.7692, Precision=0.7200, Recall=0.8257
# Glaucoma: F-score=0.5870, Precision=0.7941, Recall=0.4655
# AMD: F-score=0.2807, Precision=0.6154, Recall=0.1818
#
# --- Epoch 23 Metrics (ResNet) ---
# Average F-score: 0.5285
# DR: F-score=0.7705, Precision=0.6963, Recall=0.8624
# Glaucoma: F-score=0.5843, Precision=0.8387, Recall=0.4483
# AMD: F-score=0.2308, Precision=0.7500, Recall=0.1364
#
# --- Epoch 24 Metrics (ResNet) ---
# Average F-score: 0.4810
# DR: F-score=0.7422, Precision=0.6463, Recall=0.8716
# Glaucoma: F-score=0.7009, Precision=0.6949, Recall=0.7069
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Epoch 25 Metrics (ResNet) ---
# Average F-score: 0.4664
# DR: F-score=0.7435, Precision=0.6250, Recall=0.9174
# Glaucoma: F-score=0.4634, Precision=0.7917, Recall=0.3276
# AMD: F-score=0.1923, Precision=0.6250, Recall=0.1136
#
# --- Task 1.2 Final Metrics (ResNet) ---
# Average F-score: 0.5166
# DR: F-score=0.8201, Precision=0.8261, Recall=0.8143
# Glaucoma: F-score=0.5867, Precision=0.8462, Recall=0.4490
# AMD: F-score=0.1429, Precision=0.3333, Recall=0.0909
# Onsite Submission saved to: Arshman-Faizan-Marwa_task1-2_res.csv

# %% [markdown]
# ## Task 1.3 Full fine-tuning

# %% [markdown]
# ## Task 1.3(a): Training and Evaluation (EfficientNet)

# %%
# --- TASK 1.3: FULL FINE-TUNING ---
print("Task 1.3: Full Fine-Tuning for EfficientNet...")

# 1. Load the model from Task 1.2 Best Weights
eff_backbone = get_loaded_backbone(efficientnet_b0, 'ckpt_efficientnet_ep50.pt')
model_eff_1_3 = TransferModel(eff_backbone).to(DEVICE)
model_eff_1_3.load_state_dict(torch.load('Arshman-Faizan-Marwa_task1-2_EffNet.pt', map_location=DEVICE))

# 2. UNFREEZE EVERYTHING (Crucial for Task 1.3)
for param in model_eff_1_3.parameters():
    param.requires_grad = True

# 3. Setup Optimizer with a MUCH LOWER Learning Rate
optimizer = optim.Adam(model_eff_1_3.parameters(), lr=2e-5)
criterion = nn.BCEWithLogitsLoss()

# 4. Train the model

task1_3_best_path = 'Arshman-Faizan-Marwa_task1-3_EffNet.pt'

best_val_f1 = 0.0
for epoch in range(1, 26): # Run for 25 epochs
    start_time = time.time()
    model_eff_1_3.train()
    
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        loss = criterion(model_eff_1_3(inputs), labels)
        loss.backward()
        optimizer.step()
        
    # Evaluate on Validation Set
    val_f1 = evaluate_and_print_metrics(model_eff_1_3, val_loader, f'Task 1.3 Val (Ep {epoch})', 'EffNet')
    
    if val_f1 > best_val_f1:
        best_val_f1 = val_f1
        torch.save(model_eff_1_3.state_dict(), task1_3_best_path)
        print(f"-> Task 1.3 Checkpoint Saved! Best Val F1: {best_val_f1:.4f}")

# 5. Final Evaluation and Submission
model_eff_1_3.load_state_dict(torch.load(task1_3_best_path))
evaluate_and_print_metrics(model_eff_1_3, offsite_loader, "Task 1.3 Final", "EffNet")
# Generate the CSV for Kaggle
generate_onsite_submission(model_eff_1_3, 'Arshman-Faizan-Marwa_task1-3_eff.csv')
# Out:
# Task 1.3: Full Fine-Tuning for EfficientNet...
#
# --- Task 1.3 Val (Ep 1) Metrics (EffNet) ---
# Average F-score: 0.6876
# DR: F-score=0.7932, Precision=0.7344, Recall=0.8624
# Glaucoma: F-score=0.6667, Precision=0.8049, Recall=0.5690
# AMD: F-score=0.6027, Precision=0.7586, Recall=0.5000
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.6876
#
# --- Task 1.3 Val (Ep 2) Metrics (EffNet) ---
# Average F-score: 0.6789
# DR: F-score=0.8050, Precision=0.7348, Recall=0.8899
# Glaucoma: F-score=0.6316, Precision=0.8108, Recall=0.5172
# AMD: F-score=0.6000, Precision=0.8077, Recall=0.4773
#
# --- Task 1.3 Val (Ep 3) Metrics (EffNet) ---
# Average F-score: 0.6880
# DR: F-score=0.8049, Precision=0.7226, Recall=0.9083
# Glaucoma: F-score=0.6374, Precision=0.8788, Recall=0.5000
# AMD: F-score=0.6216, Precision=0.7667, Recall=0.5227
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.6880
#
# --- Task 1.3 Val (Ep 4) Metrics (EffNet) ---
# Average F-score: 0.6757
# DR: F-score=0.8083, Precision=0.7405, Recall=0.8899
# Glaucoma: F-score=0.6392, Precision=0.7949, Recall=0.5345
# AMD: F-score=0.5797, Precision=0.8000, Recall=0.4545
#
# --- Task 1.3 Val (Ep 5) Metrics (EffNet) ---
# Average F-score: 0.6827
# DR: F-score=0.8099, Precision=0.7368, Recall=0.8991
# Glaucoma: F-score=0.6383, Precision=0.8333, Recall=0.5172
# AMD: F-score=0.6000, Precision=0.8077, Recall=0.4773
#
# --- Task 1.3 Val (Ep 6) Metrics (EffNet) ---
# Average F-score: 0.6951
# DR: F-score=0.8235, Precision=0.7597, Recall=0.8991
# Glaucoma: F-score=0.6531, Precision=0.8000, Recall=0.5517
# AMD: F-score=0.6087, Precision=0.8400, Recall=0.4773
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.6951
#
# --- Task 1.3 Val (Ep 7) Metrics (EffNet) ---
# Average F-score: 0.7083
# DR: F-score=0.8069, Precision=0.7581, Recall=0.8624
# Glaucoma: F-score=0.6598, Precision=0.8205, Recall=0.5517
# AMD: F-score=0.6582, Precision=0.7429, Recall=0.5909
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.7083
#
# --- Task 1.3 Val (Ep 8) Metrics (EffNet) ---
# Average F-score: 0.7142
# DR: F-score=0.8305, Precision=0.7717, Recall=0.8991
# Glaucoma: F-score=0.6733, Precision=0.7907, Recall=0.5862
# AMD: F-score=0.6389, Precision=0.8214, Recall=0.5227
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.7142
#
# --- Task 1.3 Val (Ep 9) Metrics (EffNet) ---
# Average F-score: 0.7184
# DR: F-score=0.8103, Precision=0.7642, Recall=0.8624
# Glaucoma: F-score=0.7059, Precision=0.8182, Recall=0.6207
# AMD: F-score=0.6389, Precision=0.8214, Recall=0.5227
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.7184
#
# --- Task 1.3 Val (Ep 10) Metrics (EffNet) ---
# Average F-score: 0.7131
# DR: F-score=0.8087, Precision=0.7686, Recall=0.8532
# Glaucoma: F-score=0.7037, Precision=0.7600, Recall=0.6552
# AMD: F-score=0.6269, Precision=0.9130, Recall=0.4773
#
# --- Task 1.3 Val (Ep 11) Metrics (EffNet) ---
# Average F-score: 0.7237
# DR: F-score=0.8225, Precision=0.7787, Recall=0.8716
# Glaucoma: F-score=0.7184, Precision=0.8222, Recall=0.6379
# AMD: F-score=0.6301, Precision=0.7931, Recall=0.5227
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.7237
#
# --- Task 1.3 Val (Ep 12) Metrics (EffNet) ---
# Average F-score: 0.7121
# DR: F-score=0.8087, Precision=0.7686, Recall=0.8532
# Glaucoma: F-score=0.7059, Precision=0.8182, Recall=0.6207
# AMD: F-score=0.6216, Precision=0.7667, Recall=0.5227
#
# --- Task 1.3 Val (Ep 13) Metrics (EffNet) ---
# Average F-score: 0.7214
# DR: F-score=0.8240, Precision=0.7742, Recall=0.8807
# Glaucoma: F-score=0.7184, Precision=0.8222, Recall=0.6379
# AMD: F-score=0.6216, Precision=0.7667, Recall=0.5227
#
# --- Task 1.3 Val (Ep 14) Metrics (EffNet) ---
# Average F-score: 0.7272
# DR: F-score=0.8122, Precision=0.7750, Recall=0.8532
# Glaucoma: F-score=0.7115, Precision=0.8043, Recall=0.6379
# AMD: F-score=0.6579, Precision=0.7812, Recall=0.5682
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.7272
#
# --- Task 1.3 Val (Ep 15) Metrics (EffNet) ---
# Average F-score: 0.7200
# DR: F-score=0.8240, Precision=0.7742, Recall=0.8807
# Glaucoma: F-score=0.7059, Precision=0.8182, Recall=0.6207
# AMD: F-score=0.6301, Precision=0.7931, Recall=0.5227
#
# --- Task 1.3 Val (Ep 16) Metrics (EffNet) ---
# Average F-score: 0.7298
# DR: F-score=0.8170, Precision=0.7619, Recall=0.8807
# Glaucoma: F-score=0.6800, Precision=0.8095, Recall=0.5862
# AMD: F-score=0.6923, Precision=0.7941, Recall=0.6136
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.7298
#
# --- Task 1.3 Val (Ep 17) Metrics (EffNet) ---
# Average F-score: 0.7411
# DR: F-score=0.8240, Precision=0.7742, Recall=0.8807
# Glaucoma: F-score=0.7059, Precision=0.8182, Recall=0.6207
# AMD: F-score=0.6933, Precision=0.8387, Recall=0.5909
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.7411
#
# --- Task 1.3 Val (Ep 18) Metrics (EffNet) ---
# Average F-score: 0.7417
# DR: F-score=0.8225, Precision=0.7787, Recall=0.8716
# Glaucoma: F-score=0.7184, Precision=0.8222, Recall=0.6379
# AMD: F-score=0.6842, Precision=0.8125, Recall=0.5909
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.7417
#
# --- Task 1.3 Val (Ep 19) Metrics (EffNet) ---
# Average F-score: 0.7292
# DR: F-score=0.8235, Precision=0.7597, Recall=0.8991
# Glaucoma: F-score=0.7071, Precision=0.8537, Recall=0.6034
# AMD: F-score=0.6571, Precision=0.8846, Recall=0.5227
#
# --- Task 1.3 Val (Ep 20) Metrics (EffNet) ---
# Average F-score: 0.7541
# DR: F-score=0.8190, Precision=0.7724, Recall=0.8716
# Glaucoma: F-score=0.7255, Precision=0.8409, Recall=0.6379
# AMD: F-score=0.7179, Precision=0.8235, Recall=0.6364
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.7541
#
# --- Task 1.3 Val (Ep 21) Metrics (EffNet) ---
# Average F-score: 0.7607
# DR: F-score=0.8194, Precision=0.7881, Recall=0.8532
# Glaucoma: F-score=0.7379, Precision=0.8444, Recall=0.6552
# AMD: F-score=0.7250, Precision=0.8056, Recall=0.6591
# -> Task 1.3 Checkpoint Saved! Best Val F1: 0.7607
#
# --- Task 1.3 Val (Ep 22) Metrics (EffNet) ---
# Average F-score: 0.7563
# DR: F-score=0.8276, Precision=0.7805, Recall=0.8807
# Glaucoma: F-score=0.7308, Precision=0.8261, Recall=0.6552
# AMD: F-score=0.7105, Precision=0.8438, Recall=0.6136
#
# --- Task 1.3 Val (Ep 23) Metrics (EffNet) ---
# Average F-score: 0.7412
# DR: F-score=0.8158, Precision=0.7815, Recall=0.8532
# Glaucoma: F-score=0.7327, Precision=0.8605, Recall=0.6379
# AMD: F-score=0.6750, Precision=0.7500, Recall=0.6136
#
# --- Task 1.3 Val (Ep 24) Metrics (EffNet) ---
# Average F-score: 0.7348
# DR: F-score=0.8087, Precision=0.7686, Recall=0.8532
# Glaucoma: F-score=0.7115, Precision=0.8043, Recall=0.6379
# AMD: F-score=0.6842, Precision=0.8125, Recall=0.5909
#
# --- Task 1.3 Val (Ep 25) Metrics (EffNet) ---
# Average F-score: 0.7255
# DR: F-score=0.8133, Precision=0.7424, Recall=0.8991
# Glaucoma: F-score=0.6875, Precision=0.8684, Recall=0.5690
# AMD: F-score=0.6757, Precision=0.8333, Recall=0.5682
#
# --- Task 1.3 Final Metrics (EffNet) ---
# Average F-score: 0.7385
# DR: F-score=0.8613, Precision=0.8806, Recall=0.8429
# Glaucoma: F-score=0.6742, Precision=0.7500, Recall=0.6122
# AMD: F-score=0.6800, Precision=0.6071, Recall=0.7727
# Onsite Submission saved to: Arshman-Faizan-Marwa_task1-3_eff.csv

# %% [markdown]
# ## Task 1.3(b): Training and Evaluation (ResNet18)

# %%
# --- TASK 1.3: FULL FINE-TUNING FOR RESNET18 ---
print("Task 1.3: Full Fine-Tuning for ResNet18...")

# 1. Load the architecture and ResNet baseline backbone
# Using the path logic that works for your environment
res_ckpt_path = os.path.join(BASE_DIR, 'pretrained_backbone/ckpt_resnet18_ep50.pt')
res_backbone = load_backbone_only(resnet18(weights=None), res_ckpt_path)
model_res_1_3 = TransferModel(res_backbone).to(DEVICE)

# 2. LOAD YOUR BEST WEIGHTS FROM RESNET TASK 1.2
# This filename should match the save_path from your ResNet 1.2 run
task1_2_res_weights = 'Arshman-Faizan-Marwa_task1-2_ResNet.pt' 

if os.path.exists(task1_2_res_weights):
    model_res_1_3.load_state_dict(torch.load(task1_2_res_weights, map_location=DEVICE))
    print(f"Successfully loaded ResNet Task 1.2 weights.")
else:
    print(f"ERROR: {task1_2_res_weights} not found. Please check the filename.")

# 3. UNFREEZE EVERYTHING
for param in model_res_1_3.parameters():
    param.requires_grad = True

# 4. Setup Optimizer with a LOW Learning Rate (1e-5 or 2e-5)
# We use a low LR so we don't destroy the pre-trained features
optimizer = optim.Adam(model_res_1_3.parameters(), lr=2e-5)
criterion = nn.BCEWithLogitsLoss()

# 5. Training Loop
task1_3_res_best_path = 'Arshman-Faizan-Marwa_task1-3_ResNet.pt'
best_val_f1 = 0.0

for epoch in range(1, 26): # Running for 25 epochs
    model_res_1_3.train()
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        loss = criterion(model_res_1_3(inputs), labels)
        loss.backward()
        optimizer.step()
        
    # Evaluate on Validation Set
    val_f1 = evaluate_and_print_metrics(model_res_1_3, val_loader, f'Task 1.3 Val (Ep {epoch})', 'ResNet')
    
    if val_f1 > best_val_f1:
        best_val_f1 = val_f1
        torch.save(model_res_1_3.state_dict(), task1_3_res_best_path)
        print(f"-> Task 1.3 ResNet Checkpoint Saved! Best Val F1: {best_val_f1:.4f}")

# 6. Final Evaluation and Submission (Target: 78.8)
model_res_1_3.load_state_dict(torch.load(task1_3_res_best_path))
print("\n--- Final Metrics for ResNet Task 1.3 ---")
evaluate_and_print_metrics(model_res_1_3, offsite_loader, "Task 1.3 Final", "ResNet")
generate_onsite_submission(model_res_1_3, f"{TEAM_ID}_task1-3_res.csv")
# Out:
# Task 1.3: Full Fine-Tuning for ResNet18...
# Successfully loaded ResNet Task 1.2 weights.
#
# --- Task 1.3 Val (Ep 1) Metrics (ResNet) ---
# Average F-score: 0.5336
# DR: F-score=0.7722, Precision=0.6667, Recall=0.9174
# Glaucoma: F-score=0.5934, Precision=0.8182, Recall=0.4655
# AMD: F-score=0.2353, Precision=0.8571, Recall=0.1364
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.5336
#
# --- Task 1.3 Val (Ep 2) Metrics (ResNet) ---
# Average F-score: 0.5967
# DR: F-score=0.7869, Precision=0.7111, Recall=0.8807
# Glaucoma: F-score=0.6875, Precision=0.8684, Recall=0.5690
# AMD: F-score=0.3158, Precision=0.6923, Recall=0.2045
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.5967
#
# --- Task 1.3 Val (Ep 3) Metrics (ResNet) ---
# Average F-score: 0.5592
# DR: F-score=0.7760, Precision=0.6879, Recall=0.8899
# Glaucoma: F-score=0.7129, Precision=0.8372, Recall=0.6207
# AMD: F-score=0.1887, Precision=0.5556, Recall=0.1136
#
# --- Task 1.3 Val (Ep 4) Metrics (ResNet) ---
# Average F-score: 0.6264
# DR: F-score=0.8067, Precision=0.7442, Recall=0.8807
# Glaucoma: F-score=0.7568, Precision=0.7925, Recall=0.7241
# AMD: F-score=0.3158, Precision=0.6923, Recall=0.2045
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.6264
#
# --- Task 1.3 Val (Ep 5) Metrics (ResNet) ---
# Average F-score: 0.6535
# DR: F-score=0.7935, Precision=0.7101, Recall=0.8991
# Glaucoma: F-score=0.7475, Precision=0.9024, Recall=0.6379
# AMD: F-score=0.4194, Precision=0.7222, Recall=0.2955
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.6535
#
# --- Task 1.3 Val (Ep 6) Metrics (ResNet) ---
# Average F-score: 0.6809
# DR: F-score=0.8101, Precision=0.7500, Recall=0.8807
# Glaucoma: F-score=0.7477, Precision=0.8163, Recall=0.6897
# AMD: F-score=0.4848, Precision=0.7273, Recall=0.3636
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.6809
#
# --- Task 1.3 Val (Ep 7) Metrics (ResNet) ---
# Average F-score: 0.6681
# DR: F-score=0.8099, Precision=0.7368, Recall=0.8991
# Glaucoma: F-score=0.7255, Precision=0.8409, Recall=0.6379
# AMD: F-score=0.4688, Precision=0.7500, Recall=0.3409
#
# --- Task 1.3 Val (Ep 8) Metrics (ResNet) ---
# Average F-score: 0.6758
# DR: F-score=0.8083, Precision=0.7405, Recall=0.8899
# Glaucoma: F-score=0.7429, Precision=0.8298, Recall=0.6724
# AMD: F-score=0.4762, Precision=0.7895, Recall=0.3409
#
# --- Task 1.3 Val (Ep 9) Metrics (ResNet) ---
# Average F-score: 0.6818
# DR: F-score=0.8151, Precision=0.7519, Recall=0.8899
# Glaucoma: F-score=0.7379, Precision=0.8444, Recall=0.6552
# AMD: F-score=0.4923, Precision=0.7619, Recall=0.3636
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.6818
#
# --- Task 1.3 Val (Ep 10) Metrics (ResNet) ---
# Average F-score: 0.6736
# DR: F-score=0.8101, Precision=0.7500, Recall=0.8807
# Glaucoma: F-score=0.7664, Precision=0.8367, Recall=0.7069
# AMD: F-score=0.4444, Precision=0.7368, Recall=0.3182
#
# --- Task 1.3 Val (Ep 11) Metrics (ResNet) ---
# Average F-score: 0.6937
# DR: F-score=0.7967, Precision=0.7273, Recall=0.8807
# Glaucoma: F-score=0.7692, Precision=0.8696, Recall=0.6897
# AMD: F-score=0.5152, Precision=0.7727, Recall=0.3864
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.6937
#
# --- Task 1.3 Val (Ep 12) Metrics (ResNet) ---
# Average F-score: 0.6960
# DR: F-score=0.8101, Precision=0.7500, Recall=0.8807
# Glaucoma: F-score=0.7547, Precision=0.8333, Recall=0.6897
# AMD: F-score=0.5231, Precision=0.8095, Recall=0.3864
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.6960
#
# --- Task 1.3 Val (Ep 13) Metrics (ResNet) ---
# Average F-score: 0.6672
# DR: F-score=0.8000, Precision=0.7328, Recall=0.8807
# Glaucoma: F-score=0.6374, Precision=0.8788, Recall=0.5000
# AMD: F-score=0.5641, Precision=0.6471, Recall=0.5000
#
# --- Task 1.3 Val (Ep 14) Metrics (ResNet) ---
# Average F-score: 0.6988
# DR: F-score=0.8066, Precision=0.7313, Recall=0.8991
# Glaucoma: F-score=0.7525, Precision=0.8837, Recall=0.6552
# AMD: F-score=0.5373, Precision=0.7826, Recall=0.4091
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.6988
#
# --- Task 1.3 Val (Ep 15) Metrics (ResNet) ---
# Average F-score: 0.7379
# DR: F-score=0.8255, Precision=0.7698, Recall=0.8899
# Glaucoma: F-score=0.8000, Precision=0.8462, Recall=0.7586
# AMD: F-score=0.5882, Precision=0.8333, Recall=0.4545
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.7379
#
# --- Task 1.3 Val (Ep 16) Metrics (ResNet) ---
# Average F-score: 0.7201
# DR: F-score=0.8069, Precision=0.7581, Recall=0.8624
# Glaucoma: F-score=0.7619, Precision=0.8511, Recall=0.6897
# AMD: F-score=0.5915, Precision=0.7778, Recall=0.4773
#
# --- Task 1.3 Val (Ep 17) Metrics (ResNet) ---
# Average F-score: 0.7556
# DR: F-score=0.8170, Precision=0.7619, Recall=0.8807
# Glaucoma: F-score=0.8108, Precision=0.8491, Recall=0.7759
# AMD: F-score=0.6389, Precision=0.8214, Recall=0.5227
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.7556
#
# --- Task 1.3 Val (Ep 18) Metrics (ResNet) ---
# Average F-score: 0.7607
# DR: F-score=0.8270, Precision=0.7656, Recall=0.8991
# Glaucoma: F-score=0.7619, Precision=0.8511, Recall=0.6897
# AMD: F-score=0.6933, Precision=0.8387, Recall=0.5909
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.7607
#
# --- Task 1.3 Val (Ep 19) Metrics (ResNet) ---
# Average F-score: 0.7282
# DR: F-score=0.8083, Precision=0.7405, Recall=0.8899
# Glaucoma: F-score=0.7010, Precision=0.8718, Recall=0.5862
# AMD: F-score=0.6753, Precision=0.7879, Recall=0.5909
#
# --- Task 1.3 Val (Ep 20) Metrics (ResNet) ---
# Average F-score: 0.7590
# DR: F-score=0.8139, Precision=0.7705, Recall=0.8624
# Glaucoma: F-score=0.7619, Precision=0.8511, Recall=0.6897
# AMD: F-score=0.7013, Precision=0.8182, Recall=0.6136
#
# --- Task 1.3 Val (Ep 21) Metrics (ResNet) ---
# Average F-score: 0.7647
# DR: F-score=0.8348, Precision=0.7934, Recall=0.8807
# Glaucoma: F-score=0.7928, Precision=0.8302, Recall=0.7586
# AMD: F-score=0.6667, Precision=0.7647, Recall=0.5909
# -> Task 1.3 ResNet Checkpoint Saved! Best Val F1: 0.7647
#
# --- Task 1.3 Val (Ep 22) Metrics (ResNet) ---
# Average F-score: 0.7519
# DR: F-score=0.8099, Precision=0.7368, Recall=0.8991
# Glaucoma: F-score=0.7525, Precision=0.8837, Recall=0.6552
# AMD: F-score=0.6933, Precision=0.8387, Recall=0.5909
#
# --- Task 1.3 Val (Ep 23) Metrics (ResNet) ---
# Average F-score: 0.7470
# DR: F-score=0.8053, Precision=0.7778, Recall=0.8349
# Glaucoma: F-score=0.7451, Precision=0.8636, Recall=0.6552
# AMD: F-score=0.6905, Precision=0.7250, Recall=0.6591
#
# --- Task 1.3 Val (Ep 24) Metrics (ResNet) ---
# Average F-score: 0.7259
# DR: F-score=0.8122, Precision=0.7750, Recall=0.8532
# Glaucoma: F-score=0.7143, Precision=0.8750, Recall=0.6034
# AMD: F-score=0.6512, Precision=0.6667, Recall=0.6364
#
# --- Task 1.3 Val (Ep 25) Metrics (ResNet) ---
# Average F-score: 0.7328
# DR: F-score=0.8216, Precision=0.7500, Recall=0.9083
# Glaucoma: F-score=0.7010, Precision=0.8718, Recall=0.5862
# AMD: F-score=0.6757, Precision=0.8333, Recall=0.5682
#
# --- Final Metrics for ResNet Task 1.3 ---
#
# --- Task 1.3 Final Metrics (ResNet) ---
# Average F-score: 0.7572
# DR: F-score=0.9000, Precision=0.9000, Recall=0.9000
# Glaucoma: F-score=0.7527, Precision=0.7955, Recall=0.7143
# AMD: F-score=0.6190, Precision=0.6500, Recall=0.5909
# Onsite Submission saved to: Arshman-Faizan-Marwa_task1-3_res.csv

# %% [markdown]
# # Task 2: Loss Functions

# %% [markdown]
# ## Function: Focal Loss Function (multi-label, logits)

# %%
class FocalLossMultiLabel(nn.Module):
    """
    Multi-label focal loss built on BCE-with-logits.
    Works with logits of shape [B, C] and targets in {0,1} of shape [B, C].

    gamma: focusing parameter (typical: 2.0)
    alpha: balancing factor:
      - float in (0,1): same alpha for all classes (applied to positive term)
      - list/np/torch of shape [C]: per-class alpha for positive term
    reduction: 'mean' or 'sum' or 'none'
    """
    def __init__(self, gamma=2.0, alpha=0.25, reduction="mean"):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction
        self.bce = nn.BCEWithLogitsLoss(reduction="none")

    def forward(self, logits, targets):
        # BCE per element
        bce_loss = self.bce(logits, targets)  # [B, C]

        # Probabilities
        probs = torch.sigmoid(logits)  # [B, C]
        pt = probs * targets + (1 - probs) * (1 - targets)  # prob of the true label

        # Alpha weighting (optional)
        if self.alpha is None:
            alpha_t = 1.0
        else:
            if isinstance(self.alpha, (float, int)):
                alpha_pos = torch.full_like(targets, float(self.alpha))
            else:
                alpha_tensor = torch.tensor(self.alpha, device=logits.device, dtype=logits.dtype).view(1, -1)
                alpha_pos = alpha_tensor.expand_as(targets)
            alpha_t = alpha_pos * targets + (1 - alpha_pos) * (1 - targets)

        focal_factor = (1 - pt).pow(self.gamma)
        loss = alpha_t * focal_factor * bce_loss  # [B, C]

        if self.reduction == "mean":
            return loss.mean()
        if self.reduction == "sum":
            return loss.sum()
        return loss

# %% [markdown]
# ## Function: Class-Balanced Loss (re-weight BCE by class frequency)

# %%
class ClassBalancedBCELoss(nn.Module):
    """
    Class-Balanced BCE (multi-label).
    Uses "effective number of samples" weighting (Cui et al.) for *positive labels* per class,
    then applies that weight to the per-class BCE terms.

    beta close to 1.0 (e.g., 0.999) is typical when dataset is not huge.
    """
    def __init__(self, samples_per_class, beta=0.999, reduction="mean"):
        super().__init__()
        self.beta = beta
        self.reduction = reduction
        self.bce = nn.BCEWithLogitsLoss(reduction="none")

        spc = torch.tensor(samples_per_class, dtype=torch.float32)
        effective_num = 1.0 - torch.pow(torch.tensor(beta), spc)
        weights = (1.0 - beta) / (effective_num + 1e-12)  # [C]
        # Normalize weights to keep loss scale stable
        weights = weights / weights.sum() * len(weights)

        self.register_buffer("pos_weights", weights)  # [C]

    def forward(self, logits, targets):
        # BCE per element [B, C]
        bce_loss = self.bce(logits, targets)

        # Apply class-balanced weight to positive labels only
        # weight matrix: targets==1 gets pos_weights[c], targets==0 gets 1.0
        w = targets * self.pos_weights.view(1, -1) + (1 - targets) * 1.0
        loss = w * bce_loss

        if self.reduction == "mean":
            return loss.mean()
        if self.reduction == "sum":
            return loss.sum()
        return loss

# %% [markdown]
# ## Compute class stats from training dataset

# %%
def get_samples_per_class_from_df(df, disease_cols):
    # For multi-label, "samples_per_class" = number of positives for each class
    counts = df[disease_cols].sum().values.astype(np.float32)  # [C]
    # Avoid zeros (shouldn't happen here, but keep safe)
    counts = np.clip(counts, 1.0, None)
    return counts

# %% [markdown]
# ## Grad-CAM Class

# %%
class GradCAM:
    def __init__(self, model, target_layer):
        self.model = model
        self.target_layer = target_layer
        self.gradients = None
        self.activations = None
        self._register_hooks()

    def _register_hooks(self):
        def forward_hook(module, input, output):
            self.activations = output

        def backward_hook(module, grad_in, grad_out):
            self.gradients = grad_out[0]

        self.target_layer.register_forward_hook(forward_hook)
        self.target_layer.register_full_backward_hook(backward_hook)

    def generate(self, x, class_idx):
        self.model.zero_grad()
        outputs = self.model(x.to(next(self.model.parameters()).device))
        score = outputs[:, class_idx].sum()
        score.backward(retain_graph=True)

        weights = self.gradients.mean(dim=(2, 3), keepdim=True)
        cam = (weights * self.activations).sum(dim=1)
        cam = F.relu(cam)

        cam = cam - cam.min()
        cam = cam / (cam.max() + 1e-8)
        return cam

# %%
def get_gradcam_target_layer(model, backbone):
    if backbone == "resnet":
        return model.backbone.layer4[-1]

    elif backbone == "efficientnet":
        # Find last Conv2d layer automatically
        for module in reversed(list(model.backbone.modules())):
            if isinstance(module, torch.nn.Conv2d):
                return module
        raise RuntimeError("No Conv2d layer found in EfficientNet backbone")

    else:
        raise ValueError(f"Unsupported backbone: {backbone}")

# %% [markdown]
# ## GradCAM Attention Regularization

# %%
def attention_regularization(cam):
    cam = cam.view(cam.size(0), -1)
    cam = cam / (cam.sum(dim=1, keepdim=True) + 1e-8)
    entropy = -torch.sum(cam * torch.log(cam + 1e-8), dim=1)
    return entropy.mean()

# %%
def cam_attention_alignment_loss(cam, attn):
    """
    cam:  (1, H, W)
    attn: (1, C, 1, 1)
    """
    cam = cam.unsqueeze(1)                 # (1,1,H,W)
    cam = F.interpolate(cam, size=(1,1), mode="bilinear")
    cam = cam.squeeze()                    # scalar proxy

    attn = attn.mean()                     # scalar proxy

    return (cam - attn).abs()

# %% [markdown]
# ## Training loop: full fine-tuning using a custom loss and GradCAM

# %%
def train_full_finetune_with_loss(
    model,
    loss_fn,
    epochs,
    lr,
    model_label,
    task_label,
    save_path,
):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scaler = GradScaler()
    best_val_f1 = -1.0

    for epoch in range(1, epochs + 1):
        model.train()
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            # ---------- AMP FORWARD ----------
            with torch.amp.autocast(device_type=DEVICE.type):
                logits = model(inputs)
                loss = loss_fn(logits, labels)

                # ===== Grad-CAM Guided Learning (Task 4) =====
                with torch.enable_grad():
                    # Get predicted class per sample
                    pred_classes = torch.argmax(torch.sigmoid(logits), dim=1)
                
                    # Identify target layer ONCE
                    backbone = model.backbone
                    if hasattr(backbone, "layer4"):            # ResNet
                        target_layer = backbone.layer4[-1]
                    elif hasattr(backbone, "features"):        # EfficientNet
                        target_layer = backbone.features[-1]
                    else:
                        target_layer = None
                
                    if target_layer is not None:
                        cam_generator = GradCAM(model, target_layer)
                
                        cam_loss = 0.0
                        valid_samples = 0
                
                        for i in range(inputs.size(0)):
                            cls_idx = pred_classes[i].item()
                
                            # Skip AMD if you want (optional but defensible)
                            if cls_idx == 2:
                                continue
                
                            cam = cam_generator.generate(inputs[i:i+1], cls_idx)
                            # --- CAM–Attention alignment ---
                            if hasattr(model, "attn") and hasattr(model.attn, "last_attention"):
                                attn_map = model.attn.last_attention
                                cam_loss += cam_attention_alignment_loss(cam, attn_map)
                            else:
                                cam_loss += attention_regularization(cam)
                            valid_samples += 1
                
                        if valid_samples > 0:
                            cam_loss = cam_loss / valid_samples
                            loss = loss + 0.01 * cam_loss


            # ---------- AMP BACKWARD ----------
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

        val_f1 = evaluate_and_print_metrics(model, val_loader, f"{task_label} Val (Ep {epoch})", model_label)

        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            torch.save(model.state_dict(), save_path)
            print(f"-> Saved best checkpoint to {save_path} | Best Val F1: {best_val_f1:.4f}")

    return save_path

# %% [markdown]
# ## Shared statistics for losses

# %%
# --- shared statistics for losses ---
pos_counts = train_df[DISEASE_COLUMNS].sum().values.astype(np.float32)
total = float(len(train_df))
pos_rate = pos_counts / total

# Per-class alpha heuristic (more weight for minority positives), normalized
alpha_per_class = (1.0 - pos_rate)
alpha_per_class = (alpha_per_class / alpha_per_class.sum()) * len(alpha_per_class)

samples_per_class = get_samples_per_class_from_df(train_df, DISEASE_COLUMNS)

# %% [markdown]
# ## Task 2.1(a): Training and Evaluation (EfficientNet)

# %%
# -----------------------------
# TASK 2.1: Focal Loss (EffNet)
# -----------------------------
print("\n--- TASK 2.1: Focal Loss (EffNet) ---")

eff_ckpt_path = os.path.join(BASE_DIR, 'pretrained_backbone/ckpt_efficientnet_ep50.pt')
eff_backbone = load_backbone_only(efficientnet_b0(weights=None), eff_ckpt_path)
model_eff_2_1 = TransferModel(eff_backbone).to(DEVICE)

for p in model_eff_2_1.parameters():
    p.requires_grad = True

criterion_focal = FocalLossMultiLabel(gamma=1.0, alpha=0.5, reduction="mean")

task2_1_eff_best_path = 'Arshman-Faizan-Marwa_task2-1_EffNet.pt'
train_full_finetune_with_loss(
    model=model_eff_2_1,
    loss_fn=criterion_focal,
    epochs=25,
    lr=2e-5,
    model_label="EffNet",
    task_label="Task 2.1 (Focal)",
    save_path=task2_1_eff_best_path
)

model_eff_2_1.load_state_dict(torch.load(task2_1_eff_best_path, map_location=DEVICE))
print("\n--- Task 2.1 Final Metrics (Offsite) EffNet ---")
evaluate_and_print_metrics(model_eff_2_1, offsite_loader, "Task 2.1 Final (Offsite)", "EffNet")
generate_onsite_submission(model_eff_2_1, f"{TEAM_ID}_task2-1_eff.csv")
# Out:
# --- TASK 2.1: Focal Loss (EffNet) ---
#
# --- Task 2.1 (Focal) Val (Ep 1) Metrics (EffNet) ---
# Average F-score: 0.2008
# DR: F-score=0.1000, Precision=0.5455, Recall=0.0550
# Glaucoma: F-score=0.5024, Precision=0.3490, Recall=0.8966
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_EffNet.pt | Best Val F1: 0.2008
#
# --- Task 2.1 (Focal) Val (Ep 2) Metrics (EffNet) ---
# Average F-score: 0.3215
# DR: F-score=0.3946, Precision=0.7632, Recall=0.2661
# Glaucoma: F-score=0.5700, Precision=0.4014, Recall=0.9828
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_EffNet.pt | Best Val F1: 0.3215
#
# --- Task 2.1 (Focal) Val (Ep 3) Metrics (EffNet) ---
# Average F-score: 0.3263
# DR: F-score=0.3134, Precision=0.8400, Recall=0.1927
# Glaucoma: F-score=0.5022, Precision=0.3373, Recall=0.9828
# AMD: F-score=0.1633, Precision=0.8000, Recall=0.0909
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_EffNet.pt | Best Val F1: 0.3263
#
# --- Task 2.1 (Focal) Val (Ep 4) Metrics (EffNet) ---
# Average F-score: 0.3216
# DR: F-score=0.1525, Precision=1.0000, Recall=0.0826
# Glaucoma: F-score=0.5158, Precision=0.3497, Recall=0.9828
# AMD: F-score=0.2963, Precision=0.8000, Recall=0.1818
#
# --- Task 2.1 (Focal) Val (Ep 5) Metrics (EffNet) ---
# Average F-score: 0.4117
# DR: F-score=0.3676, Precision=0.9259, Recall=0.2294
# Glaucoma: F-score=0.5403, Precision=0.3725, Recall=0.9828
# AMD: F-score=0.3273, Precision=0.8182, Recall=0.2045
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_EffNet.pt | Best Val F1: 0.4117
#
# --- Task 2.1 (Focal) Val (Ep 6) Metrics (EffNet) ---
# Average F-score: 0.4803
# DR: F-score=0.4058, Precision=0.9655, Recall=0.2569
# Glaucoma: F-score=0.5714, Precision=0.4058, Recall=0.9655
# AMD: F-score=0.4638, Precision=0.6400, Recall=0.3636
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_EffNet.pt | Best Val F1: 0.4803
#
# --- Task 2.1 (Focal) Val (Ep 7) Metrics (EffNet) ---
# Average F-score: 0.4813
# DR: F-score=0.4795, Precision=0.9459, Recall=0.3211
# Glaucoma: F-score=0.5644, Precision=0.3958, Recall=0.9828
# AMD: F-score=0.4000, Precision=0.7500, Recall=0.2727
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_EffNet.pt | Best Val F1: 0.4813
#
# --- Task 2.1 (Focal) Val (Ep 8) Metrics (EffNet) ---
# Average F-score: 0.4209
# DR: F-score=0.3582, Precision=0.9600, Recall=0.2202
# Glaucoma: F-score=0.5377, Precision=0.3701, Recall=0.9828
# AMD: F-score=0.3667, Precision=0.6875, Recall=0.2500
#
# --- Task 2.1 (Focal) Val (Ep 9) Metrics (EffNet) ---
# Average F-score: 0.4952
# DR: F-score=0.4507, Precision=0.9697, Recall=0.2936
# Glaucoma: F-score=0.5588, Precision=0.3904, Recall=0.9828
# AMD: F-score=0.4762, Precision=0.7895, Recall=0.3409
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_EffNet.pt | Best Val F1: 0.4952
#
# --- Task 2.1 (Focal) Val (Ep 10) Metrics (EffNet) ---
# Average F-score: 0.4584
# DR: F-score=0.3359, Precision=1.0000, Recall=0.2018
# Glaucoma: F-score=0.5616, Precision=0.3931, Recall=0.9828
# AMD: F-score=0.4776, Precision=0.6957, Recall=0.3636
#
# --- Task 2.1 (Focal) Val (Ep 11) Metrics (EffNet) ---
# Average F-score: 0.4305
# DR: F-score=0.2835, Precision=1.0000, Recall=0.1651
# Glaucoma: F-score=0.5534, Precision=0.3851, Recall=0.9828
# AMD: F-score=0.4545, Precision=0.6818, Recall=0.3409
#
# --- Task 2.1 (Focal) Val (Ep 12) Metrics (EffNet) ---
# Average F-score: 0.3679
# DR: F-score=0.2131, Precision=1.0000, Recall=0.1193
# Glaucoma: F-score=0.4978, Precision=0.3333, Recall=0.9828
# AMD: F-score=0.3929, Precision=0.9167, Recall=0.2500
#
# --- Task 2.1 (Focal) Val (Ep 13) Metrics (EffNet) ---
# Average F-score: 0.3323
# DR: F-score=0.1043, Precision=1.0000, Recall=0.0550
# Glaucoma: F-score=0.5044, Precision=0.3393, Recall=0.9828
# AMD: F-score=0.3881, Precision=0.5652, Recall=0.2955
#
# --- Task 2.1 (Focal) Val (Ep 14) Metrics (EffNet) ---
# Average F-score: 0.3415
# DR: F-score=0.0708, Precision=1.0000, Recall=0.0367
# Glaucoma: F-score=0.5022, Precision=0.3373, Recall=0.9828
# AMD: F-score=0.4516, Precision=0.7778, Recall=0.3182
#
# --- Task 2.1 (Focal) Val (Ep 15) Metrics (EffNet) ---
# Average F-score: 0.3040
# DR: F-score=0.0536, Precision=1.0000, Recall=0.0275
# Glaucoma: F-score=0.4790, Precision=0.3167, Recall=0.9828
# AMD: F-score=0.3793, Precision=0.7857, Recall=0.2500
#
# --- Task 2.1 (Focal) Val (Ep 16) Metrics (EffNet) ---
# Average F-score: 0.3086
# DR: F-score=0.0536, Precision=1.0000, Recall=0.0275
# Glaucoma: F-score=0.4851, Precision=0.3220, Recall=0.9828
# AMD: F-score=0.3871, Precision=0.6667, Recall=0.2727
#
# --- Task 2.1 (Focal) Val (Ep 17) Metrics (EffNet) ---
# Average F-score: 0.4641
# DR: F-score=0.3231, Precision=1.0000, Recall=0.1927
# Glaucoma: F-score=0.6000, Precision=0.4318, Recall=0.9828
# AMD: F-score=0.4691, Precision=0.5135, Recall=0.4318
#
# --- Task 2.1 (Focal) Val (Ep 18) Metrics (EffNet) ---
# Average F-score: 0.3398
# DR: F-score=0.1043, Precision=1.0000, Recall=0.0550
# Glaucoma: F-score=0.5089, Precision=0.3434, Recall=0.9828
# AMD: F-score=0.4062, Precision=0.6500, Recall=0.2955
#
# --- Task 2.1 (Focal) Val (Ep 19) Metrics (EffNet) ---
# Average F-score: 0.4898
# DR: F-score=0.3182, Precision=0.9130, Recall=0.1927
# Glaucoma: F-score=0.5833, Precision=0.4179, Recall=0.9655
# AMD: F-score=0.5679, Precision=0.6216, Recall=0.5227
#
# --- Task 2.1 (Focal) Val (Ep 20) Metrics (EffNet) ---
# Average F-score: 0.2827
# DR: F-score=0.0708, Precision=1.0000, Recall=0.0367
# Glaucoma: F-score=0.4754, Precision=0.3118, Recall=1.0000
# AMD: F-score=0.3019, Precision=0.8889, Recall=0.1818
#
# --- Task 2.1 (Focal) Val (Ep 21) Metrics (EffNet) ---
# Average F-score: 0.3410
# DR: F-score=0.0877, Precision=1.0000, Recall=0.0459
# Glaucoma: F-score=0.4978, Precision=0.3333, Recall=0.9828
# AMD: F-score=0.4375, Precision=0.7000, Recall=0.3182
#
# --- Task 2.1 (Focal) Val (Ep 22) Metrics (EffNet) ---
# Average F-score: 0.3337
# DR: F-score=0.0877, Precision=1.0000, Recall=0.0459
# Glaucoma: F-score=0.4872, Precision=0.3239, Recall=0.9828
# AMD: F-score=0.4262, Precision=0.7647, Recall=0.2955
#
# --- Task 2.1 (Focal) Val (Ep 23) Metrics (EffNet) ---
# Average F-score: 0.3055
# DR: F-score=0.1833, Precision=1.0000, Recall=0.1009
# Glaucoma: F-score=0.4691, Precision=0.3081, Recall=0.9828
# AMD: F-score=0.2642, Precision=0.7778, Recall=0.1591
#
# --- Task 2.1 (Focal) Val (Ep 24) Metrics (EffNet) ---
# Average F-score: 0.4872
# DR: F-score=0.3582, Precision=0.9600, Recall=0.2202
# Glaucoma: F-score=0.5758, Precision=0.4071, Recall=0.9828
# AMD: F-score=0.5278, Precision=0.6786, Recall=0.4318
#
# --- Task 2.1 (Focal) Val (Ep 25) Metrics (EffNet) ---
# Average F-score: 0.3509
# DR: F-score=0.1043, Precision=1.0000, Recall=0.0550
# Glaucoma: F-score=0.5135, Precision=0.3476, Recall=0.9828
# AMD: F-score=0.4348, Precision=0.6000, Recall=0.3409
#
# --- Task 2.1 Final Metrics (Offsite) EffNet ---
#
# --- Task 2.1 Final (Offsite) Metrics (EffNet) ---
# Average F-score: 0.4388
# DR: F-score=0.4068, Precision=0.9730, Recall=0.2571
# Glaucoma: F-score=0.4772, Precision=0.3176, Recall=0.9592
# AMD: F-score=0.4324, Precision=0.5333, Recall=0.3636
# Onsite Submission saved to: Arshman-Faizan-Marwa_task2-1eff.csv

# %% [markdown]
# ## Task 2.1(b): Training and Evaluation (ResNet18)

# %%
# -----------------------------
# TASK 2.1: Focal Loss (ResNet)
# -----------------------------
print("\n--- TASK 2.1: Focal Loss (ResNet) ---")

res_ckpt_path = os.path.join(BASE_DIR, 'pretrained_backbone/ckpt_resnet18_ep50.pt')
res_backbone = load_backbone_only(resnet18(weights=None), res_ckpt_path)
model_res_2_1 = TransferModel(res_backbone).to(DEVICE)

for p in model_res_2_1.parameters():
    p.requires_grad = True

criterion_focal = FocalLossMultiLabel(gamma=1.0, alpha=0.5, reduction="mean")

task2_1_res_best_path = 'Arshman-Faizan-Marwa_task2-1_ResNet.pt'
train_full_finetune_with_loss(
    model=model_res_2_1,
    loss_fn=criterion_focal,
    epochs=25,
    lr=2e-5,
    model_label="ResNet",
    task_label="Task 2.1 (Focal)",
    save_path=task2_1_res_best_path
)

model_res_2_1.load_state_dict(torch.load(task2_1_res_best_path, map_location=DEVICE))
print("\n--- Task 2.1 Final Metrics (Offsite) ResNet ---")
evaluate_and_print_metrics(model_res_2_1, offsite_loader, "Task 2.1 Final (Offsite)", "ResNet")
generate_onsite_submission(model_res_2_1, f"{TEAM_ID}_task2-1_res.csv")
# Out:
# --- TASK 2.1: Focal Loss (ResNet) ---
#
# --- Task 2.1 (Focal) Val (Ep 1) Metrics (ResNet) ---
# Average F-score: 0.3890
# DR: F-score=0.6920, Precision=0.6406, Recall=0.7523
# Glaucoma: F-score=0.4750, Precision=0.8636, Recall=0.3276
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_ResNet.pt | Best Val F1: 0.3890
#
# --- Task 2.1 (Focal) Val (Ep 2) Metrics (ResNet) ---
# Average F-score: 0.5281
# DR: F-score=0.6736, Precision=0.7738, Recall=0.5963
# Glaucoma: F-score=0.7255, Precision=0.8409, Recall=0.6379
# AMD: F-score=0.1852, Precision=0.5000, Recall=0.1136
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_ResNet.pt | Best Val F1: 0.5281
#
# --- Task 2.1 (Focal) Val (Ep 3) Metrics (ResNet) ---
# Average F-score: 0.5419
# DR: F-score=0.6593, Precision=0.8219, Recall=0.5505
# Glaucoma: F-score=0.7521, Precision=0.7458, Recall=0.7586
# AMD: F-score=0.2143, Precision=0.5000, Recall=0.1364
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_ResNet.pt | Best Val F1: 0.5419
#
# --- Task 2.1 (Focal) Val (Ep 4) Metrics (ResNet) ---
# Average F-score: 0.5778
# DR: F-score=0.6878, Precision=0.8125, Recall=0.5963
# Glaucoma: F-score=0.7000, Precision=0.8333, Recall=0.6034
# AMD: F-score=0.3457, Precision=0.3784, Recall=0.3182
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_ResNet.pt | Best Val F1: 0.5778
#
# --- Task 2.1 (Focal) Val (Ep 5) Metrics (ResNet) ---
# Average F-score: 0.5642
# DR: F-score=0.6000, Precision=0.8361, Recall=0.4679
# Glaucoma: F-score=0.7521, Precision=0.7458, Recall=0.7586
# AMD: F-score=0.3404, Precision=0.3200, Recall=0.3636
#
# --- Task 2.1 (Focal) Val (Ep 6) Metrics (ResNet) ---
# Average F-score: 0.5757
# DR: F-score=0.6243, Precision=0.8438, Recall=0.4954
# Glaucoma: F-score=0.7350, Precision=0.7288, Recall=0.7414
# AMD: F-score=0.3678, Precision=0.3721, Recall=0.3636
#
# --- Task 2.1 (Focal) Val (Ep 7) Metrics (ResNet) ---
# Average F-score: 0.5583
# DR: F-score=0.4933, Precision=0.9024, Recall=0.3394
# Glaucoma: F-score=0.7586, Precision=0.7586, Recall=0.7586
# AMD: F-score=0.4231, Precision=0.3667, Recall=0.5000
#
# --- Task 2.1 (Focal) Val (Ep 8) Metrics (ResNet) ---
# Average F-score: 0.6343
# DR: F-score=0.7662, Precision=0.8370, Recall=0.7064
# Glaucoma: F-score=0.7778, Precision=0.8400, Recall=0.7241
# AMD: F-score=0.3590, Precision=0.4118, Recall=0.3182
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_ResNet.pt | Best Val F1: 0.6343
#
# --- Task 2.1 (Focal) Val (Ep 9) Metrics (ResNet) ---
# Average F-score: 0.6058
# DR: F-score=0.6082, Precision=0.8387, Recall=0.4771
# Glaucoma: F-score=0.7692, Precision=0.8696, Recall=0.6897
# AMD: F-score=0.4400, Precision=0.3929, Recall=0.5000
#
# --- Task 2.1 (Focal) Val (Ep 10) Metrics (ResNet) ---
# Average F-score: 0.6145
# DR: F-score=0.5325, Precision=0.9111, Recall=0.3761
# Glaucoma: F-score=0.7857, Precision=0.8148, Recall=0.7586
# AMD: F-score=0.5253, Precision=0.4727, Recall=0.5909
#
# --- Task 2.1 (Focal) Val (Ep 11) Metrics (ResNet) ---
# Average F-score: 0.6774
# DR: F-score=0.7692, Precision=0.8721, Recall=0.6881
# Glaucoma: F-score=0.7692, Precision=0.8696, Recall=0.6897
# AMD: F-score=0.4938, Precision=0.5405, Recall=0.4545
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_ResNet.pt | Best Val F1: 0.6774
#
# --- Task 2.1 (Focal) Val (Ep 12) Metrics (ResNet) ---
# Average F-score: 0.5418
# DR: F-score=0.3830, Precision=0.8438, Recall=0.2477
# Glaucoma: F-score=0.7797, Precision=0.7667, Recall=0.7931
# AMD: F-score=0.4628, Precision=0.3636, Recall=0.6364
#
# --- Task 2.1 (Focal) Val (Ep 13) Metrics (ResNet) ---
# Average F-score: 0.6046
# DR: F-score=0.6845, Precision=0.8205, Recall=0.5872
# Glaucoma: F-score=0.6452, Precision=0.8571, Recall=0.5172
# AMD: F-score=0.4842, Precision=0.4510, Recall=0.5227
#
# --- Task 2.1 (Focal) Val (Ep 14) Metrics (ResNet) ---
# Average F-score: 0.4789
# DR: F-score=0.2381, Precision=0.8824, Recall=0.1376
# Glaucoma: F-score=0.7385, Precision=0.6667, Recall=0.8276
# AMD: F-score=0.4602, Precision=0.3768, Recall=0.5909
#
# --- Task 2.1 (Focal) Val (Ep 15) Metrics (ResNet) ---
# Average F-score: 0.4386
# DR: F-score=0.0870, Precision=0.8333, Recall=0.0459
# Glaucoma: F-score=0.7478, Precision=0.7544, Recall=0.7414
# AMD: F-score=0.4810, Precision=0.3333, Recall=0.8636
#
# --- Task 2.1 (Focal) Val (Ep 16) Metrics (ResNet) ---
# Average F-score: 0.6746
# DR: F-score=0.7745, Precision=0.8316, Recall=0.7248
# Glaucoma: F-score=0.7788, Precision=0.8000, Recall=0.7586
# AMD: F-score=0.4706, Precision=0.6667, Recall=0.3636
#
# --- Task 2.1 (Focal) Val (Ep 17) Metrics (ResNet) ---
# Average F-score: 0.6746
# DR: F-score=0.7302, Precision=0.8625, Recall=0.6330
# Glaucoma: F-score=0.7551, Precision=0.9250, Recall=0.6379
# AMD: F-score=0.5385, Precision=0.4667, Recall=0.6364
#
# --- Task 2.1 (Focal) Val (Ep 18) Metrics (ResNet) ---
# Average F-score: 0.6535
# DR: F-score=0.6885, Precision=0.8514, Recall=0.5780
# Glaucoma: F-score=0.7234, Precision=0.9444, Recall=0.5862
# AMD: F-score=0.5487, Precision=0.4493, Recall=0.7045
#
# --- Task 2.1 (Focal) Val (Ep 19) Metrics (ResNet) ---
# Average F-score: 0.5355
# DR: F-score=0.4800, Precision=0.8780, Recall=0.3303
# Glaucoma: F-score=0.6591, Precision=0.9667, Recall=0.5000
# AMD: F-score=0.4675, Precision=0.3273, Recall=0.8182
#
# --- Task 2.1 (Focal) Val (Ep 20) Metrics (ResNet) ---
# Average F-score: 0.6795
# DR: F-score=0.7225, Precision=0.8415, Recall=0.6330
# Glaucoma: F-score=0.7551, Precision=0.9250, Recall=0.6379
# AMD: F-score=0.5607, Precision=0.4762, Recall=0.6818
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_ResNet.pt | Best Val F1: 0.6795
#
# --- Task 2.1 (Focal) Val (Ep 21) Metrics (ResNet) ---
# Average F-score: 0.4748
# DR: F-score=0.2114, Precision=0.9286, Recall=0.1193
# Glaucoma: F-score=0.7129, Precision=0.8372, Recall=0.6207
# AMD: F-score=0.5000, Precision=0.3448, Recall=0.9091
#
# --- Task 2.1 (Focal) Val (Ep 22) Metrics (ResNet) ---
# Average F-score: 0.7202
# DR: F-score=0.8038, Precision=0.8400, Recall=0.7706
# Glaucoma: F-score=0.7928, Precision=0.8302, Recall=0.7586
# AMD: F-score=0.5641, Precision=0.6471, Recall=0.5000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-1_ResNet.pt | Best Val F1: 0.7202
#
# --- Task 2.1 (Focal) Val (Ep 23) Metrics (ResNet) ---
# Average F-score: 0.6088
# DR: F-score=0.6108, Precision=0.8793, Recall=0.4679
# Glaucoma: F-score=0.6813, Precision=0.9394, Recall=0.5345
# AMD: F-score=0.5342, Precision=0.3824, Recall=0.8864
#
# --- Task 2.1 (Focal) Val (Ep 24) Metrics (ResNet) ---
# Average F-score: 0.6172
# DR: F-score=0.6000, Precision=0.8361, Recall=0.4679
# Glaucoma: F-score=0.7400, Precision=0.8810, Recall=0.6379
# AMD: F-score=0.5116, Precision=0.3882, Recall=0.7500
#
# --- Task 2.1 (Focal) Val (Ep 25) Metrics (ResNet) ---
# Average F-score: 0.6030
# DR: F-score=0.5195, Precision=0.8889, Recall=0.3670
# Glaucoma: F-score=0.7573, Precision=0.8667, Recall=0.6724
# AMD: F-score=0.5324, Precision=0.3895, Recall=0.8409
#
# --- Task 2.1 Final Metrics (Offsite) ResNet ---
#
# --- Task 2.1 Final (Offsite) Metrics (ResNet) ---
# Average F-score: 0.6859
# DR: F-score=0.8000, Precision=0.9091, Recall=0.7143
# Glaucoma: F-score=0.8132, Precision=0.8810, Recall=0.7551
# AMD: F-score=0.4444, Precision=0.3750, Recall=0.5455
# Onsite Submission saved to: Arshman-Faizan-Marwa_task2-1res.csv

# %% [markdown]
# ## Task 2.2(a): Training and Evaluation (EfficientNet)

# %%
# --------------------------------------
# TASK 2.2: Class-Balanced BCE (EffNet)
# --------------------------------------
print("\n--- TASK 2.2: Class-Balanced BCE (EffNet) ---")

eff_ckpt_path = os.path.join(BASE_DIR, 'pretrained_backbone/ckpt_efficientnet_ep50.pt')
eff_backbone = load_backbone_only(efficientnet_b0(weights=None), eff_ckpt_path)
model_eff_2_2 = TransferModel(eff_backbone).to(DEVICE)

for p in model_eff_2_2.parameters():
    p.requires_grad = True

criterion_cb = ClassBalancedBCELoss(samples_per_class=samples_per_class, beta=0.999, reduction="mean").to(DEVICE)

task2_2_eff_best_path = 'Arshman-Faizan-Marwa_task2-2_EffNet.pt'
train_full_finetune_with_loss(
    model=model_eff_2_2,
    loss_fn=criterion_cb,
    epochs=25,
    lr=2e-5,
    model_label="EffNet",
    task_label="Task 2.2 (ClassBalanced)",
    save_path=task2_2_eff_best_path
)

model_eff_2_2.load_state_dict(torch.load(task2_2_eff_best_path, map_location=DEVICE))
print("\n--- Task 2.2 Final Metrics (Offsite) EffNet ---")
evaluate_and_print_metrics(model_eff_2_2, offsite_loader, "Task 2.2 Final (Offsite)", "EffNet")
generate_onsite_submission(model_eff_2_2, f"{TEAM_ID}_task2-2_eff.csv")
# Out:
# --- TASK 2.2: Class-Balanced BCE (EffNet) ---
#
# --- Task 2.2 (ClassBalanced) Val (Ep 1) Metrics (EffNet) ---
# Average F-score: 0.2431
# DR: F-score=0.1138, Precision=0.5000, Recall=0.0642
# Glaucoma: F-score=0.6154, Precision=0.6957, Recall=0.5517
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_EffNet.pt | Best Val F1: 0.2431
#
# --- Task 2.2 (ClassBalanced) Val (Ep 2) Metrics (EffNet) ---
# Average F-score: 0.3991
# DR: F-score=0.4645, Precision=0.7826, Recall=0.3303
# Glaucoma: F-score=0.7328, Precision=0.6575, Recall=0.8276
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_EffNet.pt | Best Val F1: 0.3991
#
# --- Task 2.2 (ClassBalanced) Val (Ep 3) Metrics (EffNet) ---
# Average F-score: 0.2559
# DR: F-score=0.1920, Precision=0.7500, Recall=0.1101
# Glaucoma: F-score=0.5758, Precision=0.4071, Recall=0.9828
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Task 2.2 (ClassBalanced) Val (Ep 4) Metrics (EffNet) ---
# Average F-score: 0.4356
# DR: F-score=0.5316, Precision=0.8571, Recall=0.3853
# Glaucoma: F-score=0.6918, Precision=0.5446, Recall=0.9483
# AMD: F-score=0.0833, Precision=0.5000, Recall=0.0455
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_EffNet.pt | Best Val F1: 0.4356
#
# --- Task 2.2 (ClassBalanced) Val (Ep 5) Metrics (EffNet) ---
# Average F-score: 0.4311
# DR: F-score=0.4085, Precision=0.8788, Recall=0.2661
# Glaucoma: F-score=0.6585, Precision=0.5094, Recall=0.9310
# AMD: F-score=0.2264, Precision=0.6667, Recall=0.1364
#
# --- Task 2.2 (ClassBalanced) Val (Ep 6) Metrics (EffNet) ---
# Average F-score: 0.3810
# DR: F-score=0.3485, Precision=1.0000, Recall=0.2110
# Glaucoma: F-score=0.6437, Precision=0.4828, Recall=0.9655
# AMD: F-score=0.1509, Precision=0.4444, Recall=0.0909
#
# --- Task 2.2 (ClassBalanced) Val (Ep 7) Metrics (EffNet) ---
# Average F-score: 0.3342
# DR: F-score=0.2812, Precision=0.9474, Recall=0.1651
# Glaucoma: F-score=0.5644, Precision=0.3958, Recall=0.9828
# AMD: F-score=0.1569, Precision=0.5714, Recall=0.0909
#
# --- Task 2.2 (ClassBalanced) Val (Ep 8) Metrics (EffNet) ---
# Average F-score: 0.5695
# DR: F-score=0.5263, Precision=0.9302, Recall=0.3670
# Glaucoma: F-score=0.6887, Precision=0.5591, Recall=0.8966
# AMD: F-score=0.4935, Precision=0.5758, Recall=0.4318
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_EffNet.pt | Best Val F1: 0.5695
#
# --- Task 2.2 (ClassBalanced) Val (Ep 9) Metrics (EffNet) ---
# Average F-score: 0.5180
# DR: F-score=0.4476, Precision=0.9412, Recall=0.2936
# Glaucoma: F-score=0.6588, Precision=0.5000, Recall=0.9655
# AMD: F-score=0.4478, Precision=0.6522, Recall=0.3409
#
# --- Task 2.2 (ClassBalanced) Val (Ep 10) Metrics (EffNet) ---
# Average F-score: 0.5823
# DR: F-score=0.5513, Precision=0.9149, Recall=0.3945
# Glaucoma: F-score=0.6957, Precision=0.5437, Recall=0.9655
# AMD: F-score=0.5000, Precision=0.6429, Recall=0.4091
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_EffNet.pt | Best Val F1: 0.5823
#
# --- Task 2.2 (ClassBalanced) Val (Ep 11) Metrics (EffNet) ---
# Average F-score: 0.5203
# DR: F-score=0.3824, Precision=0.9630, Recall=0.2385
# Glaucoma: F-score=0.6786, Precision=0.5182, Recall=0.9828
# AMD: F-score=0.5000, Precision=0.5250, Recall=0.4773
#
# --- Task 2.2 (ClassBalanced) Val (Ep 12) Metrics (EffNet) ---
# Average F-score: 0.5350
# DR: F-score=0.3676, Precision=0.9259, Recall=0.2294
# Glaucoma: F-score=0.7172, Precision=0.5977, Recall=0.8966
# AMD: F-score=0.5200, Precision=0.4643, Recall=0.5909
#
# --- Task 2.2 (ClassBalanced) Val (Ep 13) Metrics (EffNet) ---
# Average F-score: 0.3489
# DR: F-score=0.1967, Precision=0.9231, Recall=0.1101
# Glaucoma: F-score=0.5481, Precision=0.3800, Recall=0.9828
# AMD: F-score=0.3019, Precision=0.8889, Recall=0.1818
#
# --- Task 2.2 (ClassBalanced) Val (Ep 14) Metrics (EffNet) ---
# Average F-score: 0.5446
# DR: F-score=0.4397, Precision=0.9688, Recall=0.2844
# Glaucoma: F-score=0.6588, Precision=0.5000, Recall=0.9655
# AMD: F-score=0.5352, Precision=0.7037, Recall=0.4318
#
# --- Task 2.2 (ClassBalanced) Val (Ep 15) Metrics (EffNet) ---
# Average F-score: 0.6100
# DR: F-score=0.5570, Precision=0.8980, Recall=0.4037
# Glaucoma: F-score=0.7089, Precision=0.5600, Recall=0.9655
# AMD: F-score=0.5641, Precision=0.6471, Recall=0.5000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_EffNet.pt | Best Val F1: 0.6100
#
# --- Task 2.2 (ClassBalanced) Val (Ep 16) Metrics (EffNet) ---
# Average F-score: 0.2911
# DR: F-score=0.0877, Precision=1.0000, Recall=0.0459
# Glaucoma: F-score=0.4893, Precision=0.3257, Recall=0.9828
# AMD: F-score=0.2963, Precision=0.8000, Recall=0.1818
#
# --- Task 2.2 (ClassBalanced) Val (Ep 17) Metrics (EffNet) ---
# Average F-score: 0.4440
# DR: F-score=0.2258, Precision=0.9333, Recall=0.1284
# Glaucoma: F-score=0.6129, Precision=0.4453, Recall=0.9828
# AMD: F-score=0.4932, Precision=0.6207, Recall=0.4091
#
# --- Task 2.2 (ClassBalanced) Val (Ep 18) Metrics (EffNet) ---
# Average F-score: 0.4296
# DR: F-score=0.1525, Precision=1.0000, Recall=0.0826
# Glaucoma: F-score=0.6364, Precision=0.4746, Recall=0.9655
# AMD: F-score=0.5000, Precision=0.4792, Recall=0.5227
#
# --- Task 2.2 (ClassBalanced) Val (Ep 19) Metrics (EffNet) ---
# Average F-score: 0.5569
# DR: F-score=0.4336, Precision=0.9118, Recall=0.2844
# Glaucoma: F-score=0.6550, Precision=0.4956, Recall=0.9655
# AMD: F-score=0.5823, Precision=0.6571, Recall=0.5227
#
# --- Task 2.2 (ClassBalanced) Val (Ep 20) Metrics (EffNet) ---
# Average F-score: 0.4431
# DR: F-score=0.3206, Precision=0.9545, Recall=0.1927
# Glaucoma: F-score=0.5895, Precision=0.4242, Recall=0.9655
# AMD: F-score=0.4194, Precision=0.7222, Recall=0.2955
#
# --- Task 2.2 (ClassBalanced) Val (Ep 21) Metrics (EffNet) ---
# Average F-score: 0.4198
# DR: F-score=0.2923, Precision=0.9048, Recall=0.1743
# Glaucoma: F-score=0.5534, Precision=0.3851, Recall=0.9828
# AMD: F-score=0.4138, Precision=0.8571, Recall=0.2727
#
# --- Task 2.2 (ClassBalanced) Val (Ep 22) Metrics (EffNet) ---
# Average F-score: 0.5482
# DR: F-score=0.4366, Precision=0.9394, Recall=0.2844
# Glaucoma: F-score=0.6746, Precision=0.5135, Recall=0.9828
# AMD: F-score=0.5333, Precision=0.6452, Recall=0.4545
#
# --- Task 2.2 (ClassBalanced) Val (Ep 23) Metrics (EffNet) ---
# Average F-score: 0.5008
# DR: F-score=0.3459, Precision=0.9583, Recall=0.2110
# Glaucoma: F-score=0.6087, Precision=0.4444, Recall=0.9655
# AMD: F-score=0.5479, Precision=0.6897, Recall=0.4545
#
# --- Task 2.2 (ClassBalanced) Val (Ep 24) Metrics (EffNet) ---
# Average F-score: 0.5261
# DR: F-score=0.4832, Precision=0.9000, Recall=0.3303
# Glaucoma: F-score=0.6264, Precision=0.4597, Recall=0.9828
# AMD: F-score=0.4688, Precision=0.7500, Recall=0.3409
#
# --- Task 2.2 (ClassBalanced) Val (Ep 25) Metrics (EffNet) ---
# Average F-score: 0.5604
# DR: F-score=0.4698, Precision=0.8750, Recall=0.3211
# Glaucoma: F-score=0.7059, Precision=0.5684, Recall=0.9310
# AMD: F-score=0.5055, Precision=0.4894, Recall=0.5227
#
# --- Task 2.2 Final Metrics (Offsite) EffNet ---
#
# --- Task 2.2 Final (Offsite) Metrics (EffNet) ---
# Average F-score: 0.5549
# DR: F-score=0.5312, Precision=0.9808, Recall=0.3643
# Glaucoma: F-score=0.6429, Precision=0.4945, Recall=0.9184
# AMD: F-score=0.4906, Precision=0.4194, Recall=0.5909
# Onsite Submission saved to: Arshman-Faizan-Marwa_task2-2eff.csv

# %% [markdown]
# ## Task 2.2(b): Training and Evaluation (ResNet18)

# %%
# --------------------------------------
# TASK 2.2: Class-Balanced BCE (ResNet)
# --------------------------------------
print("\n--- TASK 2.2: Class-Balanced BCE (ResNet) ---")

res_ckpt_path = os.path.join(BASE_DIR, 'pretrained_backbone/ckpt_resnet18_ep50.pt')
res_backbone = load_backbone_only(resnet18(weights=None), res_ckpt_path)
model_res_2_2 = TransferModel(res_backbone).to(DEVICE)

for p in model_res_2_2.parameters():
    p.requires_grad = True

criterion_cb = ClassBalancedBCELoss(samples_per_class=samples_per_class, beta=0.999, reduction="mean").to(DEVICE)

task2_2_res_best_path = 'Arshman-Faizan-Marwa_task2-2_ResNet.pt'
train_full_finetune_with_loss(
    model=model_res_2_2,
    loss_fn=criterion_cb,
    epochs=25,
    lr=2e-5,
    model_label="ResNet",
    task_label="Task 2.2 (ClassBalanced)",
    save_path=task2_2_res_best_path
)

model_res_2_2.load_state_dict(torch.load(task2_2_res_best_path, map_location=DEVICE))
print("\n--- Task 2.2 Final Metrics (Offsite) ResNet ---")
evaluate_and_print_metrics(model_res_2_2, offsite_loader, "Task 2.2 Final (Offsite)", "ResNet")
generate_onsite_submission(model_res_2_2, f"{TEAM_ID}_task2-2_res.csv")
# Out:
# --- TASK 2.2: Class-Balanced BCE (ResNet) ---
#
# --- Task 2.2 (ClassBalanced) Val (Ep 1) Metrics (ResNet) ---
# Average F-score: 0.2433
# DR: F-score=0.7298, Precision=0.5909, Recall=0.9541
# Glaucoma: F-score=0.0000, Precision=0.0000, Recall=0.0000
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_ResNet.pt | Best Val F1: 0.2433
#
# --- Task 2.2 (ClassBalanced) Val (Ep 2) Metrics (ResNet) ---
# Average F-score: 0.2690
# DR: F-score=0.7416, Precision=0.6266, Recall=0.9083
# Glaucoma: F-score=0.0656, Precision=0.6667, Recall=0.0345
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_ResNet.pt | Best Val F1: 0.2690
#
# --- Task 2.2 (ClassBalanced) Val (Ep 3) Metrics (ResNet) ---
# Average F-score: 0.4343
# DR: F-score=0.7130, Precision=0.6777, Recall=0.7523
# Glaucoma: F-score=0.5542, Precision=0.9200, Recall=0.3966
# AMD: F-score=0.0357, Precision=0.0833, Recall=0.0227
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_ResNet.pt | Best Val F1: 0.4343
#
# --- Task 2.2 (ClassBalanced) Val (Ep 4) Metrics (ResNet) ---
# Average F-score: 0.4532
# DR: F-score=0.6417, Precision=0.7692, Recall=0.5505
# Glaucoma: F-score=0.6154, Precision=0.6957, Recall=0.5517
# AMD: F-score=0.1026, Precision=0.1176, Recall=0.0909
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_ResNet.pt | Best Val F1: 0.4532
#
# --- Task 2.2 (ClassBalanced) Val (Ep 5) Metrics (ResNet) ---
# Average F-score: 0.4969
# DR: F-score=0.6564, Precision=0.7442, Recall=0.5872
# Glaucoma: F-score=0.7184, Precision=0.8222, Recall=0.6379
# AMD: F-score=0.1159, Precision=0.1600, Recall=0.0909
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_ResNet.pt | Best Val F1: 0.4969
#
# --- Task 2.2 (ClassBalanced) Val (Ep 6) Metrics (ResNet) ---
# Average F-score: 0.5370
# DR: F-score=0.7071, Precision=0.7865, Recall=0.6422
# Glaucoma: F-score=0.7500, Precision=0.7778, Recall=0.7241
# AMD: F-score=0.1538, Precision=0.5000, Recall=0.0909
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_ResNet.pt | Best Val F1: 0.5370
#
# --- Task 2.2 (ClassBalanced) Val (Ep 7) Metrics (ResNet) ---
# Average F-score: 0.5845
# DR: F-score=0.7547, Precision=0.7767, Recall=0.7339
# Glaucoma: F-score=0.6237, Precision=0.8286, Recall=0.5000
# AMD: F-score=0.3750, Precision=0.6000, Recall=0.2727
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_ResNet.pt | Best Val F1: 0.5845
#
# --- Task 2.2 (ClassBalanced) Val (Ep 8) Metrics (ResNet) ---
# Average F-score: 0.6141
# DR: F-score=0.7292, Precision=0.8434, Recall=0.6422
# Glaucoma: F-score=0.7292, Precision=0.9211, Recall=0.6034
# AMD: F-score=0.3838, Precision=0.3455, Recall=0.4318
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_ResNet.pt | Best Val F1: 0.6141
#
# --- Task 2.2 (ClassBalanced) Val (Ep 9) Metrics (ResNet) ---
# Average F-score: 0.5112
# DR: F-score=0.4762, Precision=0.9211, Recall=0.3211
# Glaucoma: F-score=0.7069, Precision=0.7069, Recall=0.7069
# AMD: F-score=0.3505, Precision=0.3208, Recall=0.3864
#
# --- Task 2.2 (ClassBalanced) Val (Ep 10) Metrics (ResNet) ---
# Average F-score: 0.6304
# DR: F-score=0.6742, Precision=0.8696, Recall=0.5505
# Glaucoma: F-score=0.7216, Precision=0.8974, Recall=0.6034
# AMD: F-score=0.4954, Precision=0.4154, Recall=0.6136
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_ResNet.pt | Best Val F1: 0.6304
#
# --- Task 2.2 (ClassBalanced) Val (Ep 11) Metrics (ResNet) ---
# Average F-score: 0.5957
# DR: F-score=0.5625, Precision=0.8824, Recall=0.4128
# Glaucoma: F-score=0.7500, Precision=0.8478, Recall=0.6724
# AMD: F-score=0.4746, Precision=0.3784, Recall=0.6364
#
# --- Task 2.2 (ClassBalanced) Val (Ep 12) Metrics (ResNet) ---
# Average F-score: 0.5829
# DR: F-score=0.5802, Precision=0.8868, Recall=0.4312
# Glaucoma: F-score=0.6939, Precision=0.8500, Recall=0.5862
# AMD: F-score=0.4746, Precision=0.3784, Recall=0.6364
#
# --- Task 2.2 (ClassBalanced) Val (Ep 13) Metrics (ResNet) ---
# Average F-score: 0.5585
# DR: F-score=0.4933, Precision=0.9024, Recall=0.3394
# Glaucoma: F-score=0.7414, Precision=0.7414, Recall=0.7414
# AMD: F-score=0.4407, Precision=0.3514, Recall=0.5909
#
# --- Task 2.2 (ClassBalanced) Val (Ep 14) Metrics (ResNet) ---
# Average F-score: 0.5111
# DR: F-score=0.3433, Precision=0.9200, Recall=0.2110
# Glaucoma: F-score=0.7255, Precision=0.8409, Recall=0.6379
# AMD: F-score=0.4645, Precision=0.3243, Recall=0.8182
#
# --- Task 2.2 (ClassBalanced) Val (Ep 15) Metrics (ResNet) ---
# Average F-score: 0.6630
# DR: F-score=0.6957, Precision=0.8533, Recall=0.5872
# Glaucoma: F-score=0.7755, Precision=0.9500, Recall=0.6552
# AMD: F-score=0.5179, Precision=0.4265, Recall=0.6591
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_ResNet.pt | Best Val F1: 0.6630
#
# --- Task 2.2 (ClassBalanced) Val (Ep 16) Metrics (ResNet) ---
# Average F-score: 0.5127
# DR: F-score=0.4521, Precision=0.8919, Recall=0.3028
# Glaucoma: F-score=0.6190, Precision=1.0000, Recall=0.4483
# AMD: F-score=0.4671, Precision=0.3171, Recall=0.8864
#
# --- Task 2.2 (ClassBalanced) Val (Ep 17) Metrics (ResNet) ---
# Average F-score: 0.5634
# DR: F-score=0.4276, Precision=0.8611, Recall=0.2844
# Glaucoma: F-score=0.7429, Precision=0.8298, Recall=0.6724
# AMD: F-score=0.5197, Precision=0.3976, Recall=0.7500
#
# --- Task 2.2 (ClassBalanced) Val (Ep 18) Metrics (ResNet) ---
# Average F-score: 0.6693
# DR: F-score=0.6806, Precision=0.7927, Recall=0.5963
# Glaucoma: F-score=0.7400, Precision=0.8810, Recall=0.6379
# AMD: F-score=0.5872, Precision=0.4923, Recall=0.7273
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_ResNet.pt | Best Val F1: 0.6693
#
# --- Task 2.2 (ClassBalanced) Val (Ep 19) Metrics (ResNet) ---
# Average F-score: 0.6862
# DR: F-score=0.7451, Precision=0.8000, Recall=0.6972
# Glaucoma: F-score=0.7216, Precision=0.8974, Recall=0.6034
# AMD: F-score=0.5918, Precision=0.5370, Recall=0.6591
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task2-2_ResNet.pt | Best Val F1: 0.6862
#
# --- Task 2.2 (ClassBalanced) Val (Ep 20) Metrics (ResNet) ---
# Average F-score: 0.6310
# DR: F-score=0.6974, Precision=0.7907, Recall=0.6239
# Glaucoma: F-score=0.6667, Precision=1.0000, Recall=0.5000
# AMD: F-score=0.5289, Precision=0.4156, Recall=0.7273
#
# --- Task 2.2 (ClassBalanced) Val (Ep 21) Metrics (ResNet) ---
# Average F-score: 0.6325
# DR: F-score=0.5767, Precision=0.8704, Recall=0.4312
# Glaucoma: F-score=0.7692, Precision=0.8696, Recall=0.6897
# AMD: F-score=0.5517, Precision=0.4444, Recall=0.7273
#
# --- Task 2.2 (ClassBalanced) Val (Ep 22) Metrics (ResNet) ---
# Average F-score: 0.6767
# DR: F-score=0.7292, Precision=0.8434, Recall=0.6422
# Glaucoma: F-score=0.7475, Precision=0.9024, Recall=0.6379
# AMD: F-score=0.5536, Precision=0.4559, Recall=0.7045
#
# --- Task 2.2 (ClassBalanced) Val (Ep 23) Metrics (ResNet) ---
# Average F-score: 0.6208
# DR: F-score=0.6024, Precision=0.8772, Recall=0.4587
# Glaucoma: F-score=0.7368, Precision=0.9459, Recall=0.6034
# AMD: F-score=0.5231, Precision=0.3953, Recall=0.7727
#
# --- Task 2.2 (ClassBalanced) Val (Ep 24) Metrics (ResNet) ---
# Average F-score: 0.6332
# DR: F-score=0.6108, Precision=0.8793, Recall=0.4679
# Glaucoma: F-score=0.7677, Precision=0.9268, Recall=0.6552
# AMD: F-score=0.5210, Precision=0.4133, Recall=0.7045
#
# --- Task 2.2 (ClassBalanced) Val (Ep 25) Metrics (ResNet) ---
# Average F-score: 0.6598
# DR: F-score=0.6979, Precision=0.8072, Recall=0.6147
# Glaucoma: F-score=0.7174, Precision=0.9706, Recall=0.5690
# AMD: F-score=0.5641, Precision=0.4521, Recall=0.7500
#
# --- Task 2.2 Final Metrics (Offsite) ResNet ---
#
# --- Task 2.2 Final (Offsite) Metrics (ResNet) ---
# Average F-score: 0.6404
# DR: F-score=0.7918, Precision=0.9238, Recall=0.6929
# Glaucoma: F-score=0.7865, Precision=0.8750, Recall=0.7143
# AMD: F-score=0.3429, Precision=0.2500, Recall=0.5455
# Onsite Submission saved to: Arshman-Faizan-Marwa_task2-2res.csv

# %% [markdown]
# # Task 3: Attention Mechanisms (SE + Multi-head Attention)

# %% [markdown]
# ## Function: Squeeze-and-Excitation

# %%
class SEBlock(nn.Module):
    """
    Channel attention (Squeeze-and-Excitation).
    Input:  (B, C, H, W)
    Output: (B, C, H, W)
    """
    def __init__(self, channels: int, reduction: int = 16):
        super().__init__()
        hidden = max(channels // reduction, 4)
        self.pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channels, hidden, bias=True),
            nn.ReLU(inplace=True),
            nn.Linear(hidden, channels, bias=True),
            nn.Sigmoid(),
        )
        self.last_attention = None

    def forward(self, x):
        b, c, _, _ = x.shape
        s = self.pool(x).view(b, c)         # (B, C)
        w = self.fc(s).view(b, c, 1, 1)     # (B, C, 1, 1)
        self.last_attention = w.detach()
        return x * w

# %% [markdown]
# ## Function: Multi-head Attention

# %%
class SpatialMHABlock(nn.Module):
    """
    Self-attention over spatial tokens.
    Treats each spatial position as a token with embedding dim = C.
    Input:  (B, C, H, W)
    Output: (B, C, H, W)
    """
    def __init__(self, channels: int, num_heads: int = 8, dropout: float = 0.0):
        super().__init__()
        assert channels % num_heads == 0, "channels must be divisible by num_heads"
        self.norm = nn.LayerNorm(channels)
        self.mha = nn.MultiheadAttention(embed_dim=channels, num_heads=num_heads,
                                         dropout=dropout, batch_first=True)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        b, c, h, w = x.shape
        # (B, C, H, W) -> (B, HW, C)
        tokens = x.view(b, c, h * w).transpose(1, 2)
        tokens_n = self.norm(tokens)
        attn_out, _ = self.mha(tokens_n, tokens_n, tokens_n, need_weights=False)
        tokens = tokens + self.dropout(attn_out)  # residual
        # (B, HW, C) -> (B, C, H, W)
        return tokens.transpose(1, 2).view(b, c, h, w)

# %% [markdown]
# ## Attention-enabled models for ResNet18
# ### (uses your pretrained backbone checkpoints via load_backbone_only())

# %%
class ResNet18WithAttention(nn.Module):
    def __init__(self, resnet_backbone: nn.Module, attention: str = "none",
                 num_classes: int = 3, se_reduction: int = 16, mha_heads: int = 8):
        super().__init__()
        self.backbone = resnet_backbone  # already loaded with your checkpoint
        self.feature_extractor = nn.Sequential(
            self.backbone.conv1,
            self.backbone.bn1,
            self.backbone.relu,
            self.backbone.maxpool,
            self.backbone.layer1,
            self.backbone.layer2,
            self.backbone.layer3,
            self.backbone.layer4,
        )

        c = 512  # ResNet18 layer4 output channels
        if attention.lower() == "se":
            self.attn = SEBlock(c, reduction=se_reduction)
        elif attention.lower() == "mha":
            self.attn = SpatialMHABlock(c, num_heads=mha_heads, dropout=0.0)
        else:
            self.attn = nn.Identity()

        self.pool = nn.AdaptiveAvgPool2d(1)

        # same style head as your TransferModel
        self.classifier = nn.Sequential(
            nn.Linear(c, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes),
        )

    def forward(self, x):
        f = self.feature_extractor(x)       # (B, 512, H, W)
        f = self.attn(f)
        f = self.pool(f).flatten(1)         # (B, 512)
        return self.classifier(f)

# %% [markdown]
# ## Attention-enabled models for EfficientNetB0
# ### (uses your pretrained backbone checkpoints via load_backbone_only())

# %%
class EfficientNetB0WithAttention(nn.Module):
    def __init__(self, eff_backbone: nn.Module, attention: str = "none",
                 num_classes: int = 3, se_reduction: int = 16, mha_heads: int = 8):
        super().__init__()
        self.backbone = eff_backbone  # already loaded with your checkpoint
        self.features = self.backbone.features

        c = 1280  # EfficientNetB0 final feature channels
        if attention.lower() == "se":
            self.attn = SEBlock(c, reduction=se_reduction)
        elif attention.lower() == "mha":
            self.attn = SpatialMHABlock(c, num_heads=mha_heads, dropout=0.0)
        else:
            self.attn = nn.Identity()

        self.pool = nn.AdaptiveAvgPool2d(1)
        self.dropout = nn.Dropout(0.2)

        self.classifier = nn.Sequential(
            nn.Linear(c, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes),
        )

    def forward(self, x):
        f = self.features(x)                # (B, 1280, H, W)
        f = self.attn(f)
        f = self.pool(f).flatten(1)         # (B, 1280)
        f = self.dropout(f)
        return self.classifier(f)

# %% [markdown]
# ## Loss Choice

# %%
# ------------------------------------------------------------
# Loss choice: prefer your ClassBalancedBCELoss if available,
# else fallback to BCEWithLogitsLoss.
# ------------------------------------------------------------
def get_task4_loss():
    # If you already defined ClassBalancedBCELoss in Task 2, use it.
    if "ClassBalancedBCELoss" in globals():
        samples_per_class = train_df[DISEASE_COLUMNS].sum().values.astype(np.float32)
        return ClassBalancedBCELoss(samples_per_class=samples_per_class, beta=0.999, reduction="mean").to(DEVICE)
    return nn.BCEWithLogitsLoss()

# %% [markdown]
# # Task 4: Fine-tuning with GradCAM and backbone networks like Swin and Vision Transformer

# %% [markdown]
# ## Task 4.1(a): Training and Evaluation (GradCAM improved SE Attention (EffNet))

# %%
print("\n--- TASK 4.1(a): GradCAM improved SE Attention (EffNet) ---")

task4_criterion = get_task4_loss()

eff_ckpt_path = os.path.join(BASE_DIR, 'pretrained_backbone/ckpt_efficientnet_ep50.pt')
eff_backbone = load_backbone_only(efficientnet_b0(weights=None), eff_ckpt_path)

model_se_eff_4_1 = EfficientNetB0WithAttention(
    eff_backbone=eff_backbone,
    attention="se",
    num_classes=3,
    se_reduction=16,
    mha_heads=8
).to(DEVICE)

for p in model_se_eff_4_1.parameters():
    p.requires_grad = True

task4_1_se_eff_best_path = "Arshman-Faizan-Marwa_task4-1_SE_EffNet.pt"

train_full_finetune_with_loss(
    model=model_se_eff_4_1,
    loss_fn=task4_criterion,
    epochs=25,
    lr=2e-5,
    model_label="EffNet",
    task_label="Task 4.1(a) SE",
    save_path=task4_1_se_eff_best_path
)

model_se_eff_4_1.load_state_dict(torch.load(task4_1_se_eff_best_path, map_location=DEVICE))
evaluate_and_print_metrics(model_se_eff_4_1, offsite_loader, "Task 4.1(a) Final Offsite", "SE EffNet")
generate_onsite_submission(model_se_eff_4_1, f"{TEAM_ID}_task4-1_se_eff.csv")
# Out:
# --- TASK 4.1(a): GradCAM improved SE Attention (EffNet) ---
#
# --- Task 4.1(a) SE Val (Ep 1) Metrics (EffNet) ---
# Average F-score: 0.2705
# DR: F-score=0.2222, Precision=0.8235, Recall=0.1284
# Glaucoma: F-score=0.5893, Precision=0.6111, Recall=0.5690
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_EffNet.pt | Best Val F1: 0.2705
#
# --- Task 4.1(a) SE Val (Ep 2) Metrics (EffNet) ---
# Average F-score: 0.3972
# DR: F-score=0.5207, Precision=0.7333, Recall=0.4037
# Glaucoma: F-score=0.6710, Precision=0.5361, Recall=0.8966
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_EffNet.pt | Best Val F1: 0.3972
#
# --- Task 4.1(a) SE Val (Ep 3) Metrics (EffNet) ---
# Average F-score: 0.4158
# DR: F-score=0.5967, Precision=0.7500, Recall=0.4954
# Glaucoma: F-score=0.6506, Precision=0.5000, Recall=0.9310
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_EffNet.pt | Best Val F1: 0.4158
#
# --- Task 4.1(a) SE Val (Ep 4) Metrics (EffNet) ---
# Average F-score: 0.3747
# DR: F-score=0.5422, Precision=0.7895, Recall=0.4128
# Glaucoma: F-score=0.5820, Precision=0.4198, Recall=0.9483
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Task 4.1(a) SE Val (Ep 5) Metrics (EffNet) ---
# Average F-score: 0.3295
# DR: F-score=0.4533, Precision=0.8293, Recall=0.3119
# Glaucoma: F-score=0.5352, Precision=0.3677, Recall=0.9828
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Task 4.1(a) SE Val (Ep 6) Metrics (EffNet) ---
# Average F-score: 0.2992
# DR: F-score=0.3862, Precision=0.7778, Recall=0.2569
# Glaucoma: F-score=0.5114, Precision=0.3478, Recall=0.9655
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Task 4.1(a) SE Val (Ep 7) Metrics (EffNet) ---
# Average F-score: 0.5521
# DR: F-score=0.6778, Precision=0.8592, Recall=0.5596
# Glaucoma: F-score=0.6707, Precision=0.5189, Recall=0.9483
# AMD: F-score=0.3077, Precision=1.0000, Recall=0.1818
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_EffNet.pt | Best Val F1: 0.5521
#
# --- Task 4.1(a) SE Val (Ep 8) Metrics (EffNet) ---
# Average F-score: 0.2873
# DR: F-score=0.3529, Precision=0.8889, Recall=0.2202
# Glaucoma: F-score=0.5089, Precision=0.3434, Recall=0.9828
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Task 4.1(a) SE Val (Ep 9) Metrics (EffNet) ---
# Average F-score: 0.5525
# DR: F-score=0.5098, Precision=0.8864, Recall=0.3578
# Glaucoma: F-score=0.6550, Precision=0.4956, Recall=0.9655
# AMD: F-score=0.4928, Precision=0.6800, Recall=0.3864
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_EffNet.pt | Best Val F1: 0.5525
#
# --- Task 4.1(a) SE Val (Ep 10) Metrics (EffNet) ---
# Average F-score: 0.6177
# DR: F-score=0.6743, Precision=0.8939, Recall=0.5413
# Glaucoma: F-score=0.6628, Precision=0.5000, Recall=0.9828
# AMD: F-score=0.5161, Precision=0.8889, Recall=0.3636
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_EffNet.pt | Best Val F1: 0.6177
#
# --- Task 4.1(a) SE Val (Ep 11) Metrics (EffNet) ---
# Average F-score: 0.6038
# DR: F-score=0.6742, Precision=0.8696, Recall=0.5505
# Glaucoma: F-score=0.6707, Precision=0.5138, Recall=0.9655
# AMD: F-score=0.4667, Precision=0.8750, Recall=0.3182
#
# --- Task 4.1(a) SE Val (Ep 12) Metrics (EffNet) ---
# Average F-score: 0.5612
# DR: F-score=0.5750, Precision=0.9020, Recall=0.4220
# Glaucoma: F-score=0.6471, Precision=0.4911, Recall=0.9483
# AMD: F-score=0.4615, Precision=0.7143, Recall=0.3409
#
# --- Task 4.1(a) SE Val (Ep 13) Metrics (EffNet) ---
# Average F-score: 0.6018
# DR: F-score=0.6705, Precision=0.8806, Recall=0.5413
# Glaucoma: F-score=0.6588, Precision=0.5000, Recall=0.9655
# AMD: F-score=0.4762, Precision=0.7895, Recall=0.3409
#
# --- Task 4.1(a) SE Val (Ep 14) Metrics (EffNet) ---
# Average F-score: 0.5732
# DR: F-score=0.5359, Precision=0.9318, Recall=0.3761
# Glaucoma: F-score=0.6587, Precision=0.5046, Recall=0.9483
# AMD: F-score=0.5250, Precision=0.5833, Recall=0.4773
#
# --- Task 4.1(a) SE Val (Ep 15) Metrics (EffNet) ---
# Average F-score: 0.4533
# DR: F-score=0.3206, Precision=0.9545, Recall=0.1927
# Glaucoma: F-score=0.5616, Precision=0.3931, Recall=0.9828
# AMD: F-score=0.4776, Precision=0.6957, Recall=0.3636
#
# --- Task 4.1(a) SE Val (Ep 16) Metrics (EffNet) ---
# Average F-score: 0.6247
# DR: F-score=0.6135, Precision=0.9259, Recall=0.4587
# Glaucoma: F-score=0.6707, Precision=0.5189, Recall=0.9483
# AMD: F-score=0.5897, Precision=0.6765, Recall=0.5227
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_EffNet.pt | Best Val F1: 0.6247
#
# --- Task 4.1(a) SE Val (Ep 17) Metrics (EffNet) ---
# Average F-score: 0.4586
# DR: F-score=0.5235, Precision=0.9750, Recall=0.3578
# Glaucoma: F-score=0.5561, Precision=0.3878, Recall=0.9828
# AMD: F-score=0.2963, Precision=0.8000, Recall=0.1818
#
# --- Task 4.1(a) SE Val (Ep 18) Metrics (EffNet) ---
# Average F-score: 0.4782
# DR: F-score=0.4225, Precision=0.9091, Recall=0.2752
# Glaucoma: F-score=0.5787, Precision=0.4101, Recall=0.9828
# AMD: F-score=0.4333, Precision=0.8125, Recall=0.2955
#
# --- Task 4.1(a) SE Val (Ep 19) Metrics (EffNet) ---
# Average F-score: 0.4534
# DR: F-score=0.3459, Precision=0.9583, Recall=0.2110
# Glaucoma: F-score=0.5700, Precision=0.4014, Recall=0.9828
# AMD: F-score=0.4444, Precision=0.7368, Recall=0.3182
#
# --- Task 4.1(a) SE Val (Ep 20) Metrics (EffNet) ---
# Average F-score: 0.4457
# DR: F-score=0.4058, Precision=0.9655, Recall=0.2569
# Glaucoma: F-score=0.5455, Precision=0.3775, Recall=0.9828
# AMD: F-score=0.3860, Precision=0.8462, Recall=0.2500
#
# --- Task 4.1(a) SE Val (Ep 21) Metrics (EffNet) ---
# Average F-score: 0.4981
# DR: F-score=0.4521, Precision=0.8919, Recall=0.3028
# Glaucoma: F-score=0.5876, Precision=0.4191, Recall=0.9828
# AMD: F-score=0.4545, Precision=0.6818, Recall=0.3409
#
# --- Task 4.1(a) SE Val (Ep 22) Metrics (EffNet) ---
# Average F-score: 0.4500
# DR: F-score=0.4225, Precision=0.9091, Recall=0.2752
# Glaucoma: F-score=0.5481, Precision=0.3800, Recall=0.9828
# AMD: F-score=0.3793, Precision=0.7857, Recall=0.2500
#
# --- Task 4.1(a) SE Val (Ep 23) Metrics (EffNet) ---
# Average F-score: 0.5797
# DR: F-score=0.5786, Precision=0.9200, Recall=0.4220
# Glaucoma: F-score=0.6400, Precision=0.4786, Recall=0.9655
# AMD: F-score=0.5205, Precision=0.6552, Recall=0.4318
#
# --- Task 4.1(a) SE Val (Ep 24) Metrics (EffNet) ---
# Average F-score: 0.4319
# DR: F-score=0.3231, Precision=1.0000, Recall=0.1927
# Glaucoma: F-score=0.5352, Precision=0.3677, Recall=0.9828
# AMD: F-score=0.4375, Precision=0.7000, Recall=0.3182
#
# --- Task 4.1(a) SE Val (Ep 25) Metrics (EffNet) ---
# Average F-score: 0.4607
# DR: F-score=0.3556, Precision=0.9231, Recall=0.2202
# Glaucoma: F-score=0.5758, Precision=0.4071, Recall=0.9828
# AMD: F-score=0.4507, Precision=0.5926, Recall=0.3636
#
# --- Task 4.1(a) Final Offsite Metrics (SE EffNet) ---
# Average F-score: 0.5895
# DR: F-score=0.5628, Precision=0.9492, Recall=0.4000
# Glaucoma: F-score=0.5806, Precision=0.4245, Recall=0.9184
# AMD: F-score=0.6250, Precision=0.5769, Recall=0.6818
# Onsite Submission saved to: Arshman-Faizan-Marwa_task4-1_se_eff.csv

# %% [markdown]
# ## Task 4.1(b): Training and Evaluation (GradCAM improved SE Attention (ResNet))

# %%
print("\n--- TASK 4.1(b): GradCAM improved SE Attention (ResNet) ---")

task4_criterion = get_task4_loss()

res_ckpt_path = os.path.join(BASE_DIR, 'pretrained_backbone/ckpt_resnet18_ep50.pt')
res_backbone = load_backbone_only(resnet18(weights=None), res_ckpt_path)

model_se_res_4_1 = ResNet18WithAttention(
    resnet_backbone=res_backbone,
    attention="se",
    num_classes=3,
    se_reduction=16,
    mha_heads=8
).to(DEVICE)

for p in model_se_res_4_1.parameters():
    p.requires_grad = True

task4_1_se_res_best_path = "Arshman-Faizan-Marwa_task4-1_SE_ResNet.pt"

train_full_finetune_with_loss(
    model=model_se_res_4_1,
    loss_fn=task4_criterion,
    epochs=25,
    lr=2e-5,
    model_label="ResNet",
    task_label="Task 4.1(b) SE",
    save_path=task4_1_se_res_best_path
)

model_se_res_4_1.load_state_dict(torch.load(task4_1_se_res_best_path, map_location=DEVICE))
evaluate_and_print_metrics(model_se_res_4_1, offsite_loader, "Task 4.1(b) Final Offsite", "SE ResNet")
generate_onsite_submission(model_se_res_4_1, f"{TEAM_ID}_task4-1_se_res.csv")
# Out:
# --- TASK 4.1(b): GradCAM improved SE Attention (ResNet) ---
#
# --- Task 4.1(b) SE Val (Ep 1) Metrics (ResNet) ---
# Average F-score: 0.3813
# DR: F-score=0.7116, Precision=0.6013, Recall=0.8716
# Glaucoma: F-score=0.4324, Precision=1.0000, Recall=0.2759
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_ResNet.pt | Best Val F1: 0.3813
#
# --- Task 4.1(b) SE Val (Ep 2) Metrics (ResNet) ---
# Average F-score: 0.4990
# DR: F-score=0.6726, Precision=0.6579, Recall=0.6881
# Glaucoma: F-score=0.6458, Precision=0.8158, Recall=0.5345
# AMD: F-score=0.1786, Precision=0.4167, Recall=0.1136
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_ResNet.pt | Best Val F1: 0.4990
#
# --- Task 4.1(b) SE Val (Ep 3) Metrics (ResNet) ---
# Average F-score: 0.4944
# DR: F-score=0.7717, Precision=0.6759, Recall=0.8991
# Glaucoma: F-score=0.7115, Precision=0.8043, Recall=0.6379
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Task 4.1(b) SE Val (Ep 4) Metrics (ResNet) ---
# Average F-score: 0.5679
# DR: F-score=0.7619, Precision=0.7213, Recall=0.8073
# Glaucoma: F-score=0.7600, Precision=0.9048, Recall=0.6552
# AMD: F-score=0.1818, Precision=0.4545, Recall=0.1136
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_ResNet.pt | Best Val F1: 0.5679
#
# --- Task 4.1(b) SE Val (Ep 5) Metrics (ResNet) ---
# Average F-score: 0.6138
# DR: F-score=0.7671, Precision=0.7636, Recall=0.7706
# Glaucoma: F-score=0.7568, Precision=0.7925, Recall=0.7241
# AMD: F-score=0.3175, Precision=0.5263, Recall=0.2273
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_ResNet.pt | Best Val F1: 0.6138
#
# --- Task 4.1(b) SE Val (Ep 6) Metrics (ResNet) ---
# Average F-score: 0.6302
# DR: F-score=0.7633, Precision=0.8061, Recall=0.7248
# Glaucoma: F-score=0.7611, Precision=0.7818, Recall=0.7414
# AMD: F-score=0.3662, Precision=0.4815, Recall=0.2955
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_ResNet.pt | Best Val F1: 0.6302
#
# --- Task 4.1(b) SE Val (Ep 7) Metrics (ResNet) ---
# Average F-score: 0.6216
# DR: F-score=0.6911, Precision=0.8049, Recall=0.6055
# Glaucoma: F-score=0.7193, Precision=0.7321, Recall=0.7069
# AMD: F-score=0.4545, Precision=0.4545, Recall=0.4545
#
# --- Task 4.1(b) SE Val (Ep 8) Metrics (ResNet) ---
# Average F-score: 0.6278
# DR: F-score=0.7150, Precision=0.8214, Recall=0.6330
# Glaucoma: F-score=0.7083, Precision=0.8947, Recall=0.5862
# AMD: F-score=0.4600, Precision=0.4107, Recall=0.5227
#
# --- Task 4.1(b) SE Val (Ep 9) Metrics (ResNet) ---
# Average F-score: 0.6081
# DR: F-score=0.6395, Precision=0.8730, Recall=0.5046
# Glaucoma: F-score=0.7500, Precision=0.7778, Recall=0.7241
# AMD: F-score=0.4348, Precision=0.3521, Recall=0.5682
#
# --- Task 4.1(b) SE Val (Ep 10) Metrics (ResNet) ---
# Average F-score: 0.5604
# DR: F-score=0.4730, Precision=0.8974, Recall=0.3211
# Glaucoma: F-score=0.7593, Precision=0.8200, Recall=0.7069
# AMD: F-score=0.4490, Precision=0.3204, Recall=0.7500
#
# --- Task 4.1(b) SE Val (Ep 11) Metrics (ResNet) ---
# Average F-score: 0.6117
# DR: F-score=0.5890, Precision=0.8889, Recall=0.4404
# Glaucoma: F-score=0.7833, Precision=0.7581, Recall=0.8103
# AMD: F-score=0.4628, Precision=0.3636, Recall=0.6364
#
# --- Task 4.1(b) SE Val (Ep 12) Metrics (ResNet) ---
# Average F-score: 0.5924
# DR: F-score=0.5290, Precision=0.8913, Recall=0.3761
# Glaucoma: F-score=0.7521, Precision=0.7458, Recall=0.7586
# AMD: F-score=0.4961, Precision=0.3765, Recall=0.7273
#
# --- Task 4.1(b) SE Val (Ep 13) Metrics (ResNet) ---
# Average F-score: 0.6275
# DR: F-score=0.6182, Precision=0.9107, Recall=0.4679
# Glaucoma: F-score=0.7719, Precision=0.7857, Recall=0.7586
# AMD: F-score=0.4923, Precision=0.3721, Recall=0.7273
#
# --- Task 4.1(b) SE Val (Ep 14) Metrics (ResNet) ---
# Average F-score: 0.5780
# DR: F-score=0.5098, Precision=0.8864, Recall=0.3578
# Glaucoma: F-score=0.7455, Precision=0.7885, Recall=0.7069
# AMD: F-score=0.4789, Precision=0.3469, Recall=0.7727
#
# --- Task 4.1(b) SE Val (Ep 15) Metrics (ResNet) ---
# Average F-score: 0.5335
# DR: F-score=0.3913, Precision=0.9310, Recall=0.2477
# Glaucoma: F-score=0.7458, Precision=0.7333, Recall=0.7586
# AMD: F-score=0.4636, Precision=0.3271, Recall=0.7955
#
# --- Task 4.1(b) SE Val (Ep 16) Metrics (ResNet) ---
# Average F-score: 0.5924
# DR: F-score=0.5466, Precision=0.8462, Recall=0.4037
# Glaucoma: F-score=0.7600, Precision=0.9048, Recall=0.6552
# AMD: F-score=0.4706, Precision=0.3303, Recall=0.8182
#
# --- Task 4.1(b) SE Val (Ep 17) Metrics (ResNet) ---
# Average F-score: 0.6289
# DR: F-score=0.6012, Precision=0.9074, Recall=0.4495
# Glaucoma: F-score=0.7963, Precision=0.8600, Recall=0.7414
# AMD: F-score=0.4892, Precision=0.3579, Recall=0.7727
#
# --- Task 4.1(b) SE Val (Ep 18) Metrics (ResNet) ---
# Average F-score: 0.5780
# DR: F-score=0.4966, Precision=0.9250, Recall=0.3394
# Glaucoma: F-score=0.7478, Precision=0.7544, Recall=0.7414
# AMD: F-score=0.4895, Precision=0.3535, Recall=0.7955
#
# --- Task 4.1(b) SE Val (Ep 19) Metrics (ResNet) ---
# Average F-score: 0.6637
# DR: F-score=0.7113, Precision=0.8118, Recall=0.6330
# Glaucoma: F-score=0.7619, Precision=0.8511, Recall=0.6897
# AMD: F-score=0.5179, Precision=0.4265, Recall=0.6591
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_SE_ResNet.pt | Best Val F1: 0.6637
#
# --- Task 4.1(b) SE Val (Ep 20) Metrics (ResNet) ---
# Average F-score: 0.6054
# DR: F-score=0.5679, Precision=0.8679, Recall=0.4220
# Glaucoma: F-score=0.7769, Precision=0.7460, Recall=0.8103
# AMD: F-score=0.4715, Precision=0.3671, Recall=0.6591
#
# --- Task 4.1(b) SE Val (Ep 21) Metrics (ResNet) ---
# Average F-score: 0.5751
# DR: F-score=0.4868, Precision=0.8605, Recall=0.3394
# Glaucoma: F-score=0.7455, Precision=0.7885, Recall=0.7069
# AMD: F-score=0.4932, Precision=0.3529, Recall=0.8182
#
# --- Task 4.1(b) SE Val (Ep 22) Metrics (ResNet) ---
# Average F-score: 0.5113
# DR: F-score=0.3259, Precision=0.8462, Recall=0.2018
# Glaucoma: F-score=0.7455, Precision=0.7885, Recall=0.7069
# AMD: F-score=0.4625, Precision=0.3190, Recall=0.8409
#
# --- Task 4.1(b) SE Val (Ep 23) Metrics (ResNet) ---
# Average F-score: 0.5874
# DR: F-score=0.5385, Precision=0.8936, Recall=0.3853
# Glaucoma: F-score=0.7273, Precision=0.6984, Recall=0.7586
# AMD: F-score=0.4964, Precision=0.3656, Recall=0.7727
#
# --- Task 4.1(b) SE Val (Ep 24) Metrics (ResNet) ---
# Average F-score: 0.6112
# DR: F-score=0.5478, Precision=0.8958, Recall=0.3945
# Glaucoma: F-score=0.7748, Precision=0.8113, Recall=0.7414
# AMD: F-score=0.5109, Precision=0.3763, Recall=0.7955
#
# --- Task 4.1(b) SE Val (Ep 25) Metrics (ResNet) ---
# Average F-score: 0.6279
# DR: F-score=0.5767, Precision=0.8704, Recall=0.4312
# Glaucoma: F-score=0.8000, Precision=0.8936, Recall=0.7241
# AMD: F-score=0.5070, Precision=0.3673, Recall=0.8182
#
# --- Task 4.1(b) Final Offsite Metrics (SE ResNet) ---
# Average F-score: 0.6499
# DR: F-score=0.7479, Precision=0.9082, Recall=0.6357
# Glaucoma: F-score=0.8315, Precision=0.9250, Recall=0.7551
# AMD: F-score=0.3704, Precision=0.2542, Recall=0.6818
# Onsite Submission saved to: Arshman-Faizan-Marwa_task4-1_se_res.csv

# %% [markdown]
# ## Task 4.1(c): Training and Evaluation (GradCAM improved MHA (EffNet))

# %%
print("\n--- TASK 4.1(c): GradCAM improved Multi-Head Attention (EffNet) ---")

task4_criterion = get_task4_loss()

eff_ckpt_path = os.path.join(BASE_DIR, 'pretrained_backbone/ckpt_efficientnet_ep50.pt')
eff_backbone = load_backbone_only(efficientnet_b0(weights=None), eff_ckpt_path)

model_mha_eff_4_1 = EfficientNetB0WithAttention(
    eff_backbone=eff_backbone,
    attention="mha",
    num_classes=3,
    se_reduction=16,
    mha_heads=8
).to(DEVICE)

for p in model_mha_eff_4_1.parameters():
    p.requires_grad = True

task4_1_mha_eff_best_path = "Arshman-Faizan-Marwa_task4-1_MHA_EffNet.pt"

train_full_finetune_with_loss(
    model=model_mha_eff_4_1,
    loss_fn=task4_criterion,
    epochs=25,
    lr=2e-5,
    model_label="EffNet",
    task_label="Task 4.1(c) MHA",
    save_path=task4_1_mha_eff_best_path
)

model_mha_eff_4_1.load_state_dict(torch.load(task4_1_mha_eff_best_path, map_location=DEVICE))
evaluate_and_print_metrics(model_mha_eff_4_1, offsite_loader, "Task 4.1(c) Final Offsite", "MHA EffNet")
generate_onsite_submission(model_mha_eff_4_1, f"{TEAM_ID}_task4-1_mha_eff.csv")
# Out:
# --- TASK 4.1(c): GradCAM improved Multi-Head Attention (EffNet) ---
#
# --- Task 4.1(c) MHA Val (Ep 1) Metrics (EffNet) ---
# Average F-score: 0.3212
# DR: F-score=0.3099, Precision=0.6667, Recall=0.2018
# Glaucoma: F-score=0.6538, Precision=0.5204, Recall=0.8793
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_EffNet.pt | Best Val F1: 0.3212
#
# --- Task 4.1(c) MHA Val (Ep 2) Metrics (EffNet) ---
# Average F-score: 0.3611
# DR: F-score=0.4906, Precision=0.7800, Recall=0.3578
# Glaucoma: F-score=0.5926, Precision=0.4275, Recall=0.9655
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_EffNet.pt | Best Val F1: 0.3611
#
# --- Task 4.1(c) MHA Val (Ep 3) Metrics (EffNet) ---
# Average F-score: 0.3361
# DR: F-score=0.4056, Precision=0.8529, Recall=0.2661
# Glaucoma: F-score=0.5158, Precision=0.3497, Recall=0.9828
# AMD: F-score=0.0870, Precision=1.0000, Recall=0.0455
#
# --- Task 4.1(c) MHA Val (Ep 4) Metrics (EffNet) ---
# Average F-score: 0.4207
# DR: F-score=0.4626, Precision=0.8947, Recall=0.3119
# Glaucoma: F-score=0.5644, Precision=0.3958, Recall=0.9828
# AMD: F-score=0.2353, Precision=0.8571, Recall=0.1364
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_EffNet.pt | Best Val F1: 0.4207
#
# --- Task 4.1(c) MHA Val (Ep 5) Metrics (EffNet) ---
# Average F-score: 0.4022
# DR: F-score=0.4336, Precision=0.9118, Recall=0.2844
# Glaucoma: F-score=0.5377, Precision=0.3701, Recall=0.9828
# AMD: F-score=0.2353, Precision=0.8571, Recall=0.1364
#
# --- Task 4.1(c) MHA Val (Ep 6) Metrics (EffNet) ---
# Average F-score: 0.4300
# DR: F-score=0.4173, Precision=0.9667, Recall=0.2661
# Glaucoma: F-score=0.5455, Precision=0.3775, Recall=0.9828
# AMD: F-score=0.3273, Precision=0.8182, Recall=0.2045
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_EffNet.pt | Best Val F1: 0.4300
#
# --- Task 4.1(c) MHA Val (Ep 7) Metrics (EffNet) ---
# Average F-score: 0.3554
# DR: F-score=0.2969, Precision=1.0000, Recall=0.1743
# Glaucoma: F-score=0.5000, Precision=0.3353, Recall=0.9828
# AMD: F-score=0.2692, Precision=0.8750, Recall=0.1591
#
# --- Task 4.1(c) MHA Val (Ep 8) Metrics (EffNet) ---
# Average F-score: 0.3448
# DR: F-score=0.3077, Precision=0.9524, Recall=0.1835
# Glaucoma: F-score=0.4914, Precision=0.3276, Recall=0.9828
# AMD: F-score=0.2353, Precision=0.8571, Recall=0.1364
#
# --- Task 4.1(c) MHA Val (Ep 9) Metrics (EffNet) ---
# Average F-score: 0.4354
# DR: F-score=0.3971, Precision=1.0000, Recall=0.2477
# Glaucoma: F-score=0.5455, Precision=0.3775, Recall=0.9828
# AMD: F-score=0.3636, Precision=0.9091, Recall=0.2273
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_EffNet.pt | Best Val F1: 0.4354
#
# --- Task 4.1(c) MHA Val (Ep 10) Metrics (EffNet) ---
# Average F-score: 0.4190
# DR: F-score=0.3796, Precision=0.9286, Recall=0.2385
# Glaucoma: F-score=0.5327, Precision=0.3654, Recall=0.9828
# AMD: F-score=0.3448, Precision=0.7143, Recall=0.2273
#
# --- Task 4.1(c) MHA Val (Ep 11) Metrics (EffNet) ---
# Average F-score: 0.4822
# DR: F-score=0.4795, Precision=0.9459, Recall=0.3211
# Glaucoma: F-score=0.5534, Precision=0.3851, Recall=0.9828
# AMD: F-score=0.4138, Precision=0.8571, Recall=0.2727
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_EffNet.pt | Best Val F1: 0.4822
#
# --- Task 4.1(c) MHA Val (Ep 12) Metrics (EffNet) ---
# Average F-score: 0.5111
# DR: F-score=0.5419, Precision=0.9130, Recall=0.3853
# Glaucoma: F-score=0.5846, Precision=0.4161, Recall=0.9828
# AMD: F-score=0.4068, Precision=0.8000, Recall=0.2727
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_EffNet.pt | Best Val F1: 0.5111
#
# --- Task 4.1(c) MHA Val (Ep 13) Metrics (EffNet) ---
# Average F-score: 0.2135
# DR: F-score=0.1803, Precision=0.8462, Recall=0.1009
# Glaucoma: F-score=0.4603, Precision=0.2990, Recall=1.0000
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
#
# --- Task 4.1(c) MHA Val (Ep 14) Metrics (EffNet) ---
# Average F-score: 0.5186
# DR: F-score=0.5067, Precision=0.9268, Recall=0.3486
# Glaucoma: F-score=0.5876, Precision=0.4191, Recall=0.9828
# AMD: F-score=0.4615, Precision=0.7143, Recall=0.3409
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_EffNet.pt | Best Val F1: 0.5186
#
# --- Task 4.1(c) MHA Val (Ep 15) Metrics (EffNet) ---
# Average F-score: 0.4989
# DR: F-score=0.5000, Precision=0.9487, Recall=0.3394
# Glaucoma: F-score=0.5561, Precision=0.3878, Recall=0.9828
# AMD: F-score=0.4407, Precision=0.8667, Recall=0.2955
#
# --- Task 4.1(c) MHA Val (Ep 16) Metrics (EffNet) ---
# Average F-score: 0.4000
# DR: F-score=0.4029, Precision=0.9333, Recall=0.2569
# Glaucoma: F-score=0.5278, Precision=0.3608, Recall=0.9828
# AMD: F-score=0.2692, Precision=0.8750, Recall=0.1591
#
# --- Task 4.1(c) MHA Val (Ep 17) Metrics (EffNet) ---
# Average F-score: 0.3987
# DR: F-score=0.3231, Precision=1.0000, Recall=0.1927
# Glaucoma: F-score=0.5158, Precision=0.3497, Recall=0.9828
# AMD: F-score=0.3571, Precision=0.8333, Recall=0.2273
#
# --- Task 4.1(c) MHA Val (Ep 18) Metrics (EffNet) ---
# Average F-score: 0.3718
# DR: F-score=0.2698, Precision=1.0000, Recall=0.1560
# Glaucoma: F-score=0.5067, Precision=0.3413, Recall=0.9828
# AMD: F-score=0.3390, Precision=0.6667, Recall=0.2273
#
# --- Task 4.1(c) MHA Val (Ep 19) Metrics (EffNet) ---
# Average F-score: 0.5355
# DR: F-score=0.5359, Precision=0.9318, Recall=0.3761
# Glaucoma: F-score=0.5787, Precision=0.4101, Recall=0.9828
# AMD: F-score=0.4918, Precision=0.8824, Recall=0.3409
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_EffNet.pt | Best Val F1: 0.5355
#
# --- Task 4.1(c) MHA Val (Ep 20) Metrics (EffNet) ---
# Average F-score: 0.5174
# DR: F-score=0.5132, Precision=0.9070, Recall=0.3578
# Glaucoma: F-score=0.5644, Precision=0.3958, Recall=0.9828
# AMD: F-score=0.4746, Precision=0.9333, Recall=0.3182
#
# --- Task 4.1(c) MHA Val (Ep 21) Metrics (EffNet) ---
# Average F-score: 0.4456
# DR: F-score=0.4658, Precision=0.9189, Recall=0.3119
# Glaucoma: F-score=0.5377, Precision=0.3701, Recall=0.9828
# AMD: F-score=0.3333, Precision=0.9000, Recall=0.2045
#
# --- Task 4.1(c) MHA Val (Ep 22) Metrics (EffNet) ---
# Average F-score: 0.4270
# DR: F-score=0.3676, Precision=0.9259, Recall=0.2294
# Glaucoma: F-score=0.5205, Precision=0.3540, Recall=0.9828
# AMD: F-score=0.3929, Precision=0.9167, Recall=0.2500
#
# --- Task 4.1(c) MHA Val (Ep 23) Metrics (EffNet) ---
# Average F-score: 0.4034
# DR: F-score=0.3768, Precision=0.8966, Recall=0.2385
# Glaucoma: F-score=0.5229, Precision=0.3563, Recall=0.9828
# AMD: F-score=0.3103, Precision=0.6429, Recall=0.2045
#
# --- Task 4.1(c) MHA Val (Ep 24) Metrics (EffNet) ---
# Average F-score: 0.3252
# DR: F-score=0.1983, Precision=1.0000, Recall=0.1101
# Glaucoma: F-score=0.4810, Precision=0.3184, Recall=0.9828
# AMD: F-score=0.2963, Precision=0.8000, Recall=0.1818
#
# --- Task 4.1(c) MHA Val (Ep 25) Metrics (EffNet) ---
# Average F-score: 0.6124
# DR: F-score=0.6012, Precision=0.9074, Recall=0.4495
# Glaucoma: F-score=0.6514, Precision=0.4872, Recall=0.9828
# AMD: F-score=0.5846, Precision=0.9048, Recall=0.4318
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_EffNet.pt | Best Val F1: 0.6124
#
# --- Task 4.1(c) Final Offsite Metrics (MHA EffNet) ---
# Average F-score: 0.6061
# DR: F-score=0.6411, Precision=0.9710, Recall=0.4786
# Glaucoma: F-score=0.5660, Precision=0.4091, Recall=0.9184
# AMD: F-score=0.6111, Precision=0.7857, Recall=0.5000
# Onsite Submission saved to: Arshman-Faizan-Marwa_task4-1_mha_eff.csv

# %% [markdown]
# ## Task 4.1(d): Training and Evaluation (GradCAM improved MHA (ResNet))

# %%
print("\n--- TASK 4.1(d): GradCAM improved Multi-Head Attention (ResNet) ---")

task4_criterion = get_task4_loss()

res_ckpt_path = os.path.join(BASE_DIR, 'pretrained_backbone/ckpt_resnet18_ep50.pt')
res_backbone = load_backbone_only(resnet18(weights=None), res_ckpt_path)

model_mha_res_4_1 = ResNet18WithAttention(
    resnet_backbone=res_backbone,
    attention="mha",
    num_classes=3,
    se_reduction=16,
    mha_heads=8
).to(DEVICE)

for p in model_mha_res_4_1.parameters():
    p.requires_grad = True

task4_1_mha_res_best_path = "Arshman-Faizan-Marwa_task4-1_MHA_ResNet.pt"

train_full_finetune_with_loss(
    model=model_mha_res_4_1,
    loss_fn=task4_criterion,
    epochs=25,
    lr=2e-5,
    model_label="ResNet",
    task_label="Task 4.1(d) MHA",
    save_path=task4_1_mha_res_best_path
)

model_mha_res_4_1.load_state_dict(torch.load(task4_1_mha_res_best_path, map_location=DEVICE))
evaluate_and_print_metrics(model_mha_res_4_1, offsite_loader, "Task 4.1(d) Final Offsite", "ResNet")
generate_onsite_submission(model_mha_res_4_1, f"{TEAM_ID}_task4-1_mha_res.csv")
# Out:
# --- TASK 4.1(d): GradCAM improved Multi-Head Attention (ResNet) ---
#
# --- Task 4.1(d) MHA Val (Ep 1) Metrics (ResNet) ---
# Average F-score: 0.3240
# DR: F-score=0.7149, Precision=0.6357, Recall=0.8165
# Glaucoma: F-score=0.2571, Precision=0.7500, Recall=0.1552
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_ResNet.pt | Best Val F1: 0.3240
#
# --- Task 4.1(d) MHA Val (Ep 2) Metrics (ResNet) ---
# Average F-score: 0.4663
# DR: F-score=0.7966, Precision=0.7402, Recall=0.8624
# Glaucoma: F-score=0.6022, Precision=0.8000, Recall=0.4828
# AMD: F-score=0.0000, Precision=0.0000, Recall=0.0000
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_ResNet.pt | Best Val F1: 0.4663
#
# --- Task 4.1(d) MHA Val (Ep 3) Metrics (ResNet) ---
# Average F-score: 0.4799
# DR: F-score=0.6441, Precision=0.8382, Recall=0.5229
# Glaucoma: F-score=0.7188, Precision=0.6571, Recall=0.7931
# AMD: F-score=0.0769, Precision=0.2500, Recall=0.0455
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_ResNet.pt | Best Val F1: 0.4799
#
# --- Task 4.1(d) MHA Val (Ep 4) Metrics (ResNet) ---
# Average F-score: 0.5900
# DR: F-score=0.7590, Precision=0.8605, Recall=0.6789
# Glaucoma: F-score=0.7207, Precision=0.7547, Recall=0.6897
# AMD: F-score=0.2903, Precision=0.5000, Recall=0.2045
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_ResNet.pt | Best Val F1: 0.5900
#
# --- Task 4.1(d) MHA Val (Ep 5) Metrics (ResNet) ---
# Average F-score: 0.5733
# DR: F-score=0.5823, Precision=0.9388, Recall=0.4220
# Glaucoma: F-score=0.7273, Precision=0.6486, Recall=0.8276
# AMD: F-score=0.4103, Precision=0.4706, Recall=0.3636
#
# --- Task 4.1(d) MHA Val (Ep 6) Metrics (ResNet) ---
# Average F-score: 0.5923
# DR: F-score=0.6743, Precision=0.8939, Recall=0.5413
# Glaucoma: F-score=0.7259, Precision=0.6364, Recall=0.8448
# AMD: F-score=0.3768, Precision=0.5200, Recall=0.2955
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_ResNet.pt | Best Val F1: 0.5923
#
# --- Task 4.1(d) MHA Val (Ep 7) Metrics (ResNet) ---
# Average F-score: 0.6983
# DR: F-score=0.7660, Precision=0.9114, Recall=0.6606
# Glaucoma: F-score=0.7679, Precision=0.7963, Recall=0.7414
# AMD: F-score=0.5610, Precision=0.6053, Recall=0.5227
# -> Saved best checkpoint to Arshman-Faizan-Marwa_task4-1_MHA_ResNet.pt | Best Val F1: 0.6983
#
# --- Task 4.1(d) MHA Val (Ep 8) Metrics (ResNet) ---
# Average F-score: 0.5883
# DR: F-score=0.5290, Precision=0.8913, Recall=0.3761
# Glaucoma: F-score=0.7547, Precision=0.8333, Recall=0.6897
# AMD: F-score=0.4812, Precision=0.3596, Recall=0.7273
#
# --- Task 4.1(d) MHA Val (Ep 9) Metrics (ResNet) ---
# Average F-score: 0.6759
# DR: F-score=0.7419, Precision=0.8961, Recall=0.6330
# Glaucoma: F-score=0.7523, Precision=0.8039, Recall=0.7069
# AMD: F-score=0.5333, Precision=0.5217, Recall=0.5455
#
# --- Task 4.1(d) MHA Val (Ep 10) Metrics (ResNet) ---
# Average F-score: 0.5946
# DR: F-score=0.5325, Precision=0.9111, Recall=0.3761
# Glaucoma: F-score=0.7419, Precision=0.6970, Recall=0.7931
# AMD: F-score=0.5094, Precision=0.4355, Recall=0.6136
#
# --- Task 4.1(d) MHA Val (Ep 11) Metrics (ResNet) ---
# Average F-score: 0.5638
# DR: F-score=0.4690, Precision=0.9444, Recall=0.3119
# Glaucoma: F-score=0.7429, Precision=0.8298, Recall=0.6724
# AMD: F-score=0.4795, Precision=0.3431, Recall=0.7955
#
# --- Task 4.1(d) MHA Val (Ep 12) Metrics (ResNet) ---
# Average F-score: 0.5976
# DR: F-score=0.5605, Precision=0.9167, Recall=0.4037
# Glaucoma: F-score=0.7424, Precision=0.6622, Recall=0.8448
# AMD: F-score=0.4898, Precision=0.4444, Recall=0.5455
#
# --- Task 4.1(d) MHA Val (Ep 13) Metrics (ResNet) ---
# Average F-score: 0.6214
# DR: F-score=0.5732, Precision=0.9375, Recall=0.4128
# Glaucoma: F-score=0.7812, Precision=0.7143, Recall=0.8621
# AMD: F-score=0.5098, Precision=0.4483, Recall=0.5909
#
# --- Task 4.1(d) MHA Val (Ep 14) Metrics (ResNet) ---
# Average F-score: 0.5803
# DR: F-score=0.4552, Precision=0.9167, Recall=0.3028
# Glaucoma: F-score=0.7812, Precision=0.7143, Recall=0.8621
# AMD: F-score=0.5043, Precision=0.4085, Recall=0.6591
#
# --- Task 4.1(d) MHA Val (Ep 15) Metrics (ResNet) ---
# Average F-score: 0.4437
# DR: F-score=0.1043, Precision=1.0000, Recall=0.0550
# Glaucoma: F-score=0.7458, Precision=0.7333, Recall=0.7586
# AMD: F-score=0.4810, Precision=0.3333, Recall=0.8636
#
# --- Task 4.1(d) MHA Val (Ep 16) Metrics (ResNet) ---
# Average F-score: 0.5665
# DR: F-score=0.5000, Precision=0.8837, Recall=0.3486
# Glaucoma: F-score=0.7200, Precision=0.8571, Recall=0.6207
# AMD: F-score=0.4795, Precision=0.3431, Recall=0.7955
#
# --- Task 4.1(d) MHA Val (Ep 17) Metrics (ResNet) ---
# Average F-score: 0.5623
# DR: F-score=0.5195, Precision=0.8889, Recall=0.3670
# Glaucoma: F-score=0.6875, Precision=0.8684, Recall=0.5690
# AMD: F-score=0.4800, Precision=0.3396, Recall=0.8182
#
# --- Task 4.1(d) MHA Val (Ep 18) Metrics (ResNet) ---
# Average F-score: 0.5104
# DR: F-score=0.3231, Precision=1.0000, Recall=0.1927
# Glaucoma: F-score=0.7347, Precision=0.9000, Recall=0.6207
# AMD: F-score=0.4734, Precision=0.3200, Recall=0.9091
#
# --- Task 4.1(d) MHA Val (Ep 19) Metrics (ResNet) ---
# Average F-score: 0.5215
# DR: F-score=0.3382, Precision=0.8519, Recall=0.2110
# Glaucoma: F-score=0.7636, Precision=0.8077, Recall=0.7241
# AMD: F-score=0.4626, Precision=0.3301, Recall=0.7727
#
# --- Task 4.1(d) MHA Val (Ep 20) Metrics (ResNet) ---
# Average F-score: 0.4991
# DR: F-score=0.3358, Precision=0.8214, Recall=0.2110
# Glaucoma: F-score=0.7010, Precision=0.8718, Recall=0.5862
# AMD: F-score=0.4606, Precision=0.3140, Recall=0.8636
#
# --- Task 4.1(d) MHA Val (Ep 21) Metrics (ResNet) ---
# Average F-score: 0.5541
# DR: F-score=0.4933, Precision=0.9024, Recall=0.3394
# Glaucoma: F-score=0.6875, Precision=0.8684, Recall=0.5690
# AMD: F-score=0.4815, Precision=0.3305, Recall=0.8864
#
# --- Task 4.1(d) MHA Val (Ep 22) Metrics (ResNet) ---
# Average F-score: 0.5795
# DR: F-score=0.5098, Precision=0.8864, Recall=0.3578
# Glaucoma: F-score=0.7358, Precision=0.8125, Recall=0.6724
# AMD: F-score=0.4930, Precision=0.3571, Recall=0.7955
#
# --- Task 4.1(d) MHA Val (Ep 23) Metrics (ResNet) ---
# Average F-score: 0.4364
# DR: F-score=0.1951, Precision=0.8571, Recall=0.1101
# Glaucoma: F-score=0.6947, Precision=0.8919, Recall=0.5690
# AMD: F-score=0.4194, Precision=0.2746, Recall=0.8864
#
# --- Task 4.1(d) MHA Val (Ep 24) Metrics (ResNet) ---
# Average F-score: 0.6170
# DR: F-score=0.6703, Precision=0.8158, Recall=0.5688
# Glaucoma: F-score=0.6809, Precision=0.8889, Recall=0.5517
# AMD: F-score=0.5000, Precision=0.3646, Recall=0.7955
#
# --- Task 4.1(d) MHA Val (Ep 25) Metrics (ResNet) ---
# Average F-score: 0.5630
# DR: F-score=0.5166, Precision=0.9286, Recall=0.3578
# Glaucoma: F-score=0.7010, Precision=0.8718, Recall=0.5862
# AMD: F-score=0.4713, Precision=0.3274, Recall=0.8409
#
# --- Task 4.1(d) Final Offsite Metrics (ResNet) ---
# Average F-score: 0.7138
# DR: F-score=0.7967, Precision=0.9505, Recall=0.6857
# Glaucoma: F-score=0.7677, Precision=0.7600, Recall=0.7755
# AMD: F-score=0.5769, Precision=0.5000, Recall=0.6818
# Onsite Submission saved to: Arshman-Faizan-Marwa_task4-1_mha_res.csv

# %% [markdown]
# ## Task 4.1: Grad-CAM Visualization

# %%
import cv2
def visualize_gradcam(model, backbone, dataset, device, num_samples=3):
    model.eval()

    target_layer = get_gradcam_target_layer(model, backbone)
    if target_layer is None:
        print("Grad-CAM visualization skipped (Transformer backbone).")
        return

    cam_generator = GradCAM(model, target_layer)

    class_names = ["DR", "Glaucoma", "AMD"]

    for i in range(num_samples):
        img, label = dataset[i]
        x = img.unsqueeze(0).to(device)

        # 1️⃣ Forward pass to get predictions
        with torch.no_grad():
            outputs = model(x)

        # 2️⃣ Select most confident predicted class
        class_idx = torch.argmax(torch.sigmoid(outputs), dim=1).item()
        cls_name = class_names[class_idx]

        # 3️⃣ Generate Grad-CAM for that class
        cam = cam_generator.generate(x, class_idx)[0].detach().cpu().numpy()
        cam = cv2.resize(cam, (img.shape[2], img.shape[1]))

        img_np = img.permute(1,2,0).cpu().numpy()
        img_np = (img_np - img_np.min()) / (img_np.max() - img_np.min())

        heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)
        heatmap = heatmap / 255.0

        overlay = 0.5 * img_np + 0.5 * heatmap

        plt.figure(figsize=(4,4))
        plt.title(f"Pred: {cls_name} | GT={int(label[class_idx])}")
        plt.imshow(overlay)
        plt.axis("off")
        plt.show()

# %%
val_dataset = ODIRDataset(val_df, IMAGE_DIR, 'val')

# %%
visualize_gradcam(
    model_se_eff_4_1,
    backbone="efficientnet",
    dataset=val_dataset,
    device=DEVICE,
    num_samples=3
)

# %%
visualize_gradcam(
    model_se_res_4_1,
    backbone="resnet",
    dataset=val_dataset,
    device=DEVICE,
    num_samples=3
)

# %%
visualize_gradcam(
    model_mha_eff_4_1,
    backbone="efficientnet",
    dataset=val_dataset,
    device=DEVICE,
    num_samples=3
)

# %%
visualize_gradcam(
    model_mha_res_4_1,
    backbone="resnet",
    dataset=val_dataset,
    device=DEVICE,
    num_samples=3
)

# %% [markdown]
# ## Task 4.2 (a): Training and Evaluation (Vision Transformer)

# %%
# print("Task 4: Vision Transformer")

# vit_backbone = timm.create_model(
#     "vit_base_patch16_224",
#     pretrained=True,
#     img_size=256,
#     num_classes=0
# )

# model_vit = TransferModel(vit_backbone).to(DEVICE)

# opt = optim.Adam(model_vit.parameters(), lr=2e-5)

# best_path = train_full_finetune_with_loss(
#     model=model_vit,
#     loss_fn=nn.BCEWithLogitsLoss(),
#     epochs=25,
#     lr=2e-5,
#     model_label="ViT",
#     task_label="Task 4",
#     save_path="Arshman-Faizan-Marwa_task4-2_ViT.pt"
# )

# model_vit.load_state_dict(torch.load(best_path, map_location=DEVICE))
# evaluate_and_print_metrics(model_vit, offsite_loader, "Task 4.2a ViT Offsite", "ViT")
# generate_onsite_submission(model_vit, f"{TEAM_ID}_task4-2_vit.csv")

# %% [markdown]
# ## Task 4.2 (b): Training and Evaluation (Swin Transformer)

# %%
# print("Task 4: Swin Transformer")

# swin_backbone = timm.create_model(
#     "swin_small_patch4_window7_224",
#     pretrained=True,
#     img_size=256,
#     num_classes=0,
#     global_pool="avg"
# )

# swin_backbone.set_grad_checkpointing(True)

# model_swin = TransferModel(swin_backbone).to(DEVICE)

# for name, param in model_swin.backbone.named_parameters():
#     if "layers.0" in name or "layers.1" in name:
#         param.requires_grad = False

# opt = optim.Adam(model_swin.parameters(), lr=2e-5)

# best_path = train_full_finetune_with_loss(
#     model=model_swin,
#     loss_fn=nn.BCEWithLogitsLoss(),
#     epochs=25,
#     lr=2e-5,
#     model_label="Swin",
#     task_label="Task 4",
#     save_path="Arshman-Faizan-Marwa_task4-2_Swin.pt"
# )

# model_swin.load_state_dict(torch.load(best_path, map_location=DEVICE))
# evaluate_and_print_metrics(model_swin, offsite_loader, "Task 4.2b Swin Offsite", "Swin")
# generate_onsite_submission(model_swin, f"{TEAM_ID}_task4-2_swin.csv")
